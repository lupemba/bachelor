# %%
# %matplotlib notebook
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
omni = pd.read_pickle('/home/simon/Desktop/Bachelor_project/data/pkl_files/omni.pkl')

# %%
omni.head()
# Out:
#                      AP_INDEX   Kp   F10_INDEX  BZ_GSE   DST
# 2015-01-01 00:00:00       9.0  2.3  132.899994     1.8 -14.0
# 2015-01-01 01:00:00       9.0  2.3  132.899994     0.6 -13.0
# 2015-01-01 02:00:00       9.0  2.3  132.899994    -0.3 -15.0
# 2015-01-01 03:00:00       4.0  1.0  132.899994     0.8 -13.0
# 2015-01-01 04:00:00       4.0  1.0  132.899994     0.0 -12.0

# %%
active = np.ones(len(omni.Kp))
active[omni.Kp<4] = float('NaN')
max_dens = max(omni.Kp)
min_dens = min(omni.Kp)
plt.figure()

p1 = omni.Kp.plot( style='b',legend=True,linewidth=0.7)
p1.fill_between(omni.Kp.index,max_dens* active, np.zeros(len(active))+min_dens, color='r', alpha=0.4)
p1.set_ylabel('Kp')
plt.title('Geomagnetic active periods')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,'Geomagnetic active periods')

# %%
omni[omni.Kp<4].index
# Out:
# DatetimeIndex(['2015-01-01 00:00:00', '2015-01-01 01:00:00',
#                '2015-01-01 02:00:00', '2015-01-01 03:00:00',
#                '2015-01-01 04:00:00', '2015-01-01 05:00:00',
#                '2015-01-01 06:00:00', '2015-01-01 07:00:00',
#                '2015-01-01 08:00:00', '2015-01-01 09:00:00',
#                ...
#                '2015-06-30 14:00:00', '2015-06-30 15:00:00',
#                '2015-06-30 16:00:00', '2015-06-30 17:00:00',
#                '2015-06-30 18:00:00', '2015-06-30 19:00:00',
#                '2015-06-30 20:00:00', '2015-06-30 21:00:00',
#                '2015-06-30 22:00:00', '2015-06-30 23:00:00'],
#               dtype='datetime64[ns]', length=3984, freq=None)

# %%
len(np.unique(omni[omni.Kp>=4].index.date))
# Out:
# 43

# %% [markdown]
# # # Days with Kp> 4  which I will include

# %%
np.unique(omni[omni.Kp>=4].index.date)
# Out:
# array([datetime.date(2015, 1, 2), datetime.date(2015, 1, 3),
#        datetime.date(2015, 1, 4), datetime.date(2015, 1, 5),
#        datetime.date(2015, 1, 7), datetime.date(2015, 1, 8),
#        datetime.date(2015, 1, 26), datetime.date(2015, 2, 1),
#        datetime.date(2015, 2, 2), datetime.date(2015, 2, 3),
#        datetime.date(2015, 2, 17), datetime.date(2015, 2, 18),
#        datetime.date(2015, 2, 24), datetime.date(2015, 3, 1),
#        datetime.date(2015, 3, 2), datetime.date(2015, 3, 7),
#        datetime.date(2015, 3, 17), datetime.date(2015, 3, 18),
#        datetime.date(2015, 3, 19), datetime.date(2015, 3, 20),
#        datetime.date(2015, 3, 21), datetime.date(2015, 3, 22),
#        datetime.date(2015, 3, 23), datetime.date(2015, 3, 29),
#        datetime.date(2015, 4, 2), datetime.date(2015, 4, 10),
#        datetime.date(2015, 4, 11), datetime.date(2015, 4, 14),
#        datetime.date(2015, 4, 15), datetime.date(2015, 4, 16),
# ...
