# %% [markdown]
# # Histograms
# - try to do regresion for F10.7 and look at the residuals

# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
Half_orbit = pd.read_pickle('/home/simon/Desktop/Bachelor_project/data/pkl_files/half_orbit_means.pkl')

# %%
Half_orbit.head()
# Out:
#                      Density_norm       FAC  FAC_power       Density  \
# 2015-01-02 00:50:50  5.932167e-13  0.104478   0.284759  6.468488e-13
# 2015-01-02 01:37:45  7.720531e-13  0.139248   0.372618  6.987142e-13
# 2015-01-02 02:24:40  5.577984e-13  0.113231   0.390340  6.089699e-13
# 2015-01-02 03:11:35  7.597623e-13  0.181961   0.565810  6.858343e-13
# 2015-01-02 03:58:30  5.691719e-13  0.075313   0.165567  6.237317e-13
#
#                           Altitude  Orbit_nr  Hemisphere  AP_INDEX   Kp  \
# 2015-01-02 00:50:50  464222.287865       1.0         1.0      15.0  3.0
# 2015-01-02 01:37:45  475492.964700       1.0        -1.0      15.0  3.0
# 2015-01-02 02:24:40  464224.157119       2.0         1.0      15.0  3.0
# 2015-01-02 03:11:35  475506.057772       2.0        -1.0       4.0  1.0
# 2015-01-02 03:58:30  464035.397442       3.0         1.0       4.0  1.0
#
#                      F10_INDEX  BY_GSM  BZ_GSM  Bulk_speed    F10_Mean  \
# 2015-01-02 00:50:50      141.0    -1.0    -2.1       433.0  129.029218
# 2015-01-02 01:37:45      141.0    -0.6    -1.7       433.0  129.032511
# 2015-01-02 02:24:40      141.0    -2.2    -2.4       434.0  129.035803
# 2015-01-02 03:11:35      141.0    -3.0    -2.3       433.0  129.039095
# 2015-01-02 03:58:30      141.0    -3.0    -2.3       433.0  129.039095
#
#                        PyAmps
# 2015-01-02 00:50:50  1.769016
# 2015-01-02 01:37:45  2.962752
# 2015-01-02 02:24:40  1.880936
# 2015-01-02 03:11:35  4.111182
# 2015-01-02 03:58:30  1.841245

# %%
active = Half_orbit[Half_orbit.Kp >= 4]
quiet =  Half_orbit[Half_orbit.Kp < 4]

# %% [markdown]
# ## ALL DATA

# %%
sns.jointplot("FAC", "Density_norm", Half_orbit[Half_orbit.Hemisphere==1], ylim=[Half_orbit.Density_norm.min()*0.9,Half_orbit.Density_norm.max()*1.1]);

# %%
sns.lmplot?

# %%
Half_orbit[(Half_orbit.Density_norm<1.5*10**-12) &(Half_orbit.FAC>0.6)]
# Out:
#                      Density_norm       FAC  FAC_power       Density  \
# 2015-01-07 09:49:55  1.392264e-12  0.686514   1.783749  1.232329e-12
#
#                           Altitude  Orbit_nr  Hemisphere  AP_INDEX   Kp  \
# 2015-01-07 09:49:55  475214.005738      68.0        -1.0      94.0  6.3
#
#                       F10_INDEX  BY_GSM  BZ_GSM  Bulk_speed    F10_Mean  \
# 2015-01-07 09:49:55  142.399994     5.2   -17.4       469.0  128.644445
#
#                        PyAmps
# 2015-01-07 09:49:55  16.66029

# %%
Half_orbit[(Half_orbit.Density_norm<2*10**-12) &(Half_orbit.FAC>0.7)]
# Out:
#                      Density_norm       FAC  FAC_power       Density  \
# 2015-03-17 16:00:20  1.978391e-12  0.722576   1.718321  1.986287e-12
#
#                           Altitude  Orbit_nr  Hemisphere  AP_INDEX   Kp  \
# 2015-03-17 16:00:20  461355.735217     459.0         1.0     179.0  7.7
#
#                       F10_INDEX  BY_GSM  BZ_GSM  Bulk_speed    F10_Mean  \
# 2015-03-17 16:00:20  113.199997     5.6   -15.8       606.0  138.779835
#
#                         PyAmps
# 2015-03-17 16:00:20  18.188213

# %%
Half_orbit[(Half_orbit.Density_norm>2.5*10**-12) &(Half_orbit.FAC<0.3)]

# %%
sns.jointplot("FAC", "Density", Half_orbit, ylim=[Half_orbit.Density.min()*0.9,Half_orbit.Density.max()*1.1]);

# %%
sns.jointplot("Kp", "Density_norm", Half_orbit, ylim=[Half_orbit.Density_norm.min()*0.9,Half_orbit.Density_norm.max()*1.1]);

# %%
sns.jointplot("AP_INDEX", "Density_norm", Half_orbit, ylim=[Half_orbit.Density_norm.min()*0.9,Half_orbit.Density_norm.max()*1.1]);

# %% [markdown]
# ## Active periodes

# %%
len(active)
# Out:
# 370

# %%
with sns.axes_style('white'):
    sns.jointplot("FAC", "Density_corr", active,ylim=[active.Density.min()*0.9,active.Density.max()*1.1]);

# %%
with sns.axes_style('white'):
    sns.jointplot("FAC", "AP_INDEX", active);

# %%
with sns.axes_style('white'):
    sns.jointplot("Kp","Density_corr", active, ylim=[active.Density.min()*0.9,active.Density.max()*1.1]);

# %% [markdown]
# ## Log(FAC) & log(density)

# %%
with sns.axes_style('white'):
    sns.jointplot(active.FAC.apply(np.log), active.Density.apply(np.log));

# %%
with sns.axes_style('white'):
    sns.jointplot(active.FAC.apply(np.log), active.AP_INDEX,kind='kde');

# %%
with sns.axes_style('white'):
    sns.jointplot( active.Density.apply(np.log),active.AP_INDEX,kind='kde');

# %% [markdown]
# ## Quite periodes

# %%
with sns.axes_style('white'):
    sns.jointplot("FAC", "Density", quiet, kind='kde');

# %%
with sns.axes_style('white'):
    sns.jointplot("FAC", "AP_INDEX", quiet, kind='kde');

# %%
with sns.axes_style('white'):
    sns.jointplot("Density", "AP_INDEX", quiet, kind='kde');
