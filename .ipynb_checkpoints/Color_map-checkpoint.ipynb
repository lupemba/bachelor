# %%
# %matplotlib notebook

# %% [markdown]
# # Color_map plots

# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import My_functions_v2 as my

# %% [markdown]
# ### Find interesting periodes

# %%
Half_orbit = pd.read_pickle('/home/simon/Desktop/Bachelor_project/data/pkl_files/half_orbit_means.pkl')

# %%
plt.figure()

plt.plot(Half_orbit.Orbit_nr,Half_orbit.FAC)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()

plt.plot(Half_orbit.Orbit_nr,Half_orbit.Kp)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
FAC = pd.read_pickle('/home/simon/Desktop/Bachelor_project/data/pkl_files/FAC_filter.pkl')
DNS = pd.read_pickle('/home/simon/Desktop/Bachelor_project/data/pkl_files/DNS_corrected.pkl')
Electro_jets = pd.read_pickle('/home/simon/Desktop/Bachelor_project/data/pkl_files/Electro_jets.pkl')

# %% [markdown]
# # Color_map function

# %% [markdown]
# ### Storm Marts

# %%
lat = 'mLatitude'

# %%
DNS_Z,DNS_index,DNS_dates,DNS_orbit = my.Color_map(DNS,'2015-03-15-02',61,lat)

# %%
plt.figure()

# Formate the dates to a string
fig_date_str = DNS_dates.strftime('%d/%m %Hh')

# Plot the data
plt.imshow(np.log(DNS_Z), extent=[0, 5, 0, 5], aspect='equal', origin='lower',
           cmap='jet')
plt.colorbar()

# Set the ticks and labels...
# Create x labes
x_labels = fig_date_str[::15]
x_ticks = np.linspace(0,5-((len(fig_date_str)-1)%15)/len(fig_date_str)*5,len(x_labels))
plt.xticks(x_ticks, x_labels)
plt.xlabel('Date')

# Create y labes
y_labels = [-90,-45,0,45,90,45,0,-45,-90]
y_ticks = np.linspace(0,5,len(y_labels))
plt.yticks(y_ticks, y_labels)
plt.ylabel(lat)


plt.title('Log(Density)')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,'Log(Density)')

# %%
FAC_Z,FAC_index,FAC_dates,FAC_orbit = my.Color_map(FAC,'2015-03-15-02',61,lat,30,'20s')

# %%
plt.figure()

fig_date_str = FAC_dates.strftime('%d/%m %Hh')

plt.imshow(FAC_Z, extent=[0, 5, 0, 5], origin='lower',
           cmap='jet')
#cmap='seismic')
plt.colorbar()

# Set the ticks and labels...
x_labels = fig_date_str[::15]
x_ticks = np.linspace(0,5-((len(fig_date_str)-1)%15)/len(fig_date_str)*5,len(x_labels))
plt.xticks(x_ticks, x_labels)
plt.xlabel('Date')

y_ticks = np.linspace(0,5,9)
y_labels = [-90,-60,'$\pm$ 30',60,90,60,'$\pm$ 30',-60,-90]
plt.yticks(y_ticks, y_labels)
plt.ylabel(lat)


plt.title('abs(FAC)')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,'abs(FAC)')

# %%
Electro_jets.head()
# Out:
#                               FAC   Latitude   Longitude  Orbit_nr  \
# 2015-01-02 00:00:00.500  0.883094 -74.064067 -135.102502       0.0
# 2015-01-02 00:07:35.500  0.654653 -76.444228   22.611447       0.0
# 2015-01-02 00:47:00.500  0.526303  74.338715   33.275336       1.0
# 2015-01-02 00:55:04.500  0.459313  74.197359 -167.646185       1.0
# 2015-01-02 01:35:08.500  0.994762 -79.030489 -154.496707       1.0
#
#                          Hemisphere  mLatitude  mLongitude  mN_heading  \
# 2015-01-02 00:00:00.500        -1.0 -66.204445  -24.189478        -1.0
# 2015-01-02 00:07:35.500        -1.0 -68.704727   52.635109         1.0
# 2015-01-02 00:47:00.500         1.0  70.755402  117.962578         1.0
# 2015-01-02 00:55:04.500         1.0  71.873520 -116.674347        -1.0
# 2015-01-02 01:35:08.500        -1.0 -72.813133  -21.659479        -1.0
#
#                          Local_solar_time
# 2015-01-02 00:00:00.500         15.026789
# 2015-01-02 00:07:35.500          1.661058
# 2015-01-02 00:47:00.500          3.007088
# 2015-01-02 00:55:04.500         13.735101
# 2015-01-02 01:35:08.500         15.325064

# %%
S_jets = Electro_jets[Electro_jets.Hemisphere==-1].groupby(['Orbit_nr'])['mLatitude'].mean()
N_jets = Electro_jets[Electro_jets.Hemisphere==1].groupby(['Orbit_nr'])['mLatitude'].mean()

# %%
idx2=(S_jets.index >= FAC_orbit[0]) & (S_jets.index <= FAC_orbit[-1])

# %%
plt.figure()
plt.plot(S_jets.index,S_jets)
plt.plot(N_jets.index,N_jets,'r')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Plot_jets=Electro_jets[(Electro_jets.mN_heading==-1) &(Electro_jets.Hemisphere==1)]['2015-03-15-01':]
Plot_jets = Plot_jets.iloc[0:61,:]

# %%
plt.figure()
Plot_jets.mLatitude.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Storm January

# %%
DNS_Z,DNS_index,DNS_dates,DNS_orbit = my.Color_map(DNS,'2015-01-05-06',37,lat)

# %%
plt.figure()

# Formate the dates to a string
fig_date_str = DNS_dates.strftime('%d/%m %Hh')

# Plot the data
plt.imshow(np.log(DNS_Z), extent=[0, 5, 0, 5], aspect='equal', origin='lower',
           cmap='jet')
plt.colorbar()

# Set the ticks and labels...
# Create x labes
x_labels = fig_date_str[::12]
x_ticks = np.linspace(0,5-((len(fig_date_str)-1)%15)/len(fig_date_str)*5,len(x_labels))
plt.xticks(x_ticks, x_labels)
plt.xlabel('Date')

# Create y labes
y_labels = [-90,-45,0,45,90,45,0,-45,-90]
y_ticks = np.linspace(0,5,len(y_labels))
plt.yticks(y_ticks, y_labels)
plt.ylabel(lat)


plt.title('Log(Density)')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,'Log(Density)')

# %%
solar = DNS[DNS_dates[0]:DNS_dates[-1]]
solar = solar[abs(solar.Latitude) < 0.5]

# %%
solar
# Out:
#                           Altitude  Latitude   Longitude  Local_solar_time  \
# 2015-01-05 06:37:50  461436.847995 -0.085116  -67.609090          2.036741
# 2015-01-05 07:24:40  460077.703663  0.055642  100.639545         14.033630
# 2015-01-05 08:11:40  461388.852950  0.013042  -91.149754          2.030766
# 2015-01-05 08:58:30  460168.849033 -0.043074   77.098821         14.027652
# 2015-01-05 09:45:30  461217.779330  0.110412 -114.690765          2.024769
# 2015-01-05 10:32:10  460157.382926  0.499660   53.570064         14.019695
# 2015-01-05 10:32:20  460257.015134 -0.143529   53.557804         14.021655
# 2015-01-08 12:48:10  -91.914825         1.0       85.5
# 2015-01-08 13:34:50   77.624878        -1.0       86.0
# 2015-01-08 13:35:00   77.544525        -1.0       86.0
#
# [112 rows x 11 columns]

# %%
DNS.head()
# Out:
#                           Altitude   Latitude   Longitude  Local_solar_time  \
# 2015-01-02 00:00:10  486219.952352 -75.265076 -133.716770         15.026789
# 2015-01-02 00:00:20  486343.326722 -75.888605 -133.288864         15.058092
# 2015-01-02 00:00:30  486461.701815 -76.511095 -132.818524         15.092225
# 2015-01-02 00:00:40  486575.028978 -77.132404 -132.299675         15.129592
# 2015-01-02 00:00:50  486683.264306 -77.752361 -131.725048         15.170678
#
#                           Density  Orbit_nr  Hemisphere  mLatitude  \
# 2015-01-02 00:00:10  7.548359e-13       0.0        -1.0 -66.886017
# 2015-01-02 00:00:20  7.497549e-13       0.0        -1.0 -67.286018
# 2015-01-02 00:00:30  7.387672e-13       0.0        -1.0 -67.674911
# 2015-01-02 00:00:40  7.249351e-13       0.0        -1.0 -68.052132
# 2015-01-02 00:00:50  7.045834e-13       0.0        -1.0 -68.417084
#
#                      mLongitude  mN_heading  mOrbit_nr
# 2015-01-02 00:00:10  -21.511412        -1.0        0.0
# 2015-01-02 00:00:20  -20.244268        -1.0        0.0
# 2015-01-02 00:00:30  -18.936092        -1.0        0.0
# 2015-01-02 00:00:40  -17.586060        -1.0        0.0
# 2015-01-02 00:00:50  -16.193459        -1.0        0.0

# %%
FAC_Z,FAC_index,FAC_dates,FAC_orbit = my.Color_map(FAC,'2015-01-05-06',37,lat,30,'20s')

# %%
plt.figure()

fig_date_str = FAC_dates.strftime('%d/%m %Hh')

plt.imshow(FAC_Z, extent=[0, 5, 0, 5], origin='lower',
           cmap='jet')
#cmap='seismic')
plt.colorbar()

# Set the ticks and labels...
x_labels = fig_date_str[::15]
x_ticks = np.linspace(0,5-((len(fig_date_str)-1)%15)/len(fig_date_str)*5,len(x_labels))
plt.xticks(x_ticks, x_labels)
plt.xlabel('Date')

y_ticks = np.linspace(0,5,9)
y_labels = [-90,-60,'$\pm$ 30',60,90,60,'$\pm$ 30',-60,-90]
plt.yticks(y_ticks, y_labels)
plt.ylabel(lat)


plt.title('abs(FAC)')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,'abs(FAC)')

# %%
Plot_jets=Electro_jets[(Electro_jets.mN_heading==1) &(Electro_jets.Hemisphere==-1)]['2015-01-05-06':]
Plot_jets = Plot_jets.iloc[0:37,:]

# %%
plt.figure()
Plot_jets.mLatitude.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()

plt.subplot(1, 2, 1)
plt.imshow(np.log(DNS_Z), extent=[0, 5, 0, 5], origin='lower',
           cmap='jet')
#plt.colorbar()
plt.axis(aspect='image')
plt.title('log(Density)')

plt.subplot(1, 2, 2)

plt.imshow(FAC_Z, extent=[0, 5, 0, 5], origin='lower',
           cmap='jet')
#plt.colorbar()
plt.axis(aspect='image')
plt.title('FAC')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,'FAC')
