# %%
# %matplotlib notebook

# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import My_functions_v2 as my

# %%
FAC = pd.read_pickle('/home/simon/Desktop/Bachelor_project/data/pkl_files/FAC_filter.pkl')
DNS = pd.read_pickle('/home/simon/Desktop/Bachelor_project/data/pkl_files/DNS.pkl')
Half_orbit = pd.read_pickle('/home/simon/Desktop/Bachelor_project/data/pkl_files/half_orbit_and_omni.pkl')

# %%
plt.figure()

plt.plot(Half_orbit.Orbit_nr,Half_orbit.Density)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Half_orbit.head()
# Out:
#                           FAC  FAC_power       Density  Orbit_nr  Hemisphere  \
# 2015-01-02 00:50:50  0.104478   0.284759  6.468488e-13       1.0         1.0
# 2015-01-02 01:37:45  0.139248   0.372618  6.987142e-13       1.0        -1.0
# 2015-01-02 02:24:40  0.113231   0.390340  6.089699e-13       2.0         1.0
# 2015-01-02 03:11:35  0.181961   0.565810  6.858343e-13       2.0        -1.0
# 2015-01-02 03:58:30  0.075313   0.165567  6.237317e-13       3.0         1.0
#
#                      AP_INDEX   Kp  F10_INDEX  BZ_GSE   DST    F10_Mean
# 2015-01-02 00:50:50      15.0  3.0      141.0    -1.8 -22.0  156.571399
# 2015-01-02 01:37:45      15.0  3.0      141.0    -1.5 -21.0  156.586008
# 2015-01-02 02:24:40      15.0  3.0      141.0    -1.9 -16.0  156.600617
# 2015-01-02 03:11:35       4.0  1.0      141.0    -1.8  -7.0  156.615226
# 2015-01-02 03:58:30       4.0  1.0      141.0    -1.8  -7.0  156.615226

# %%
FAC.head()
# Out:
#                           Latitude   Longitude        Radius       IRC  \
# 2015-01-02 00:00:00.500 -74.064067 -135.102502  6.844350e+06 -0.849996
# 2015-01-02 00:00:01.500 -74.126940 -135.067437  6.844351e+06 -0.694960
# 2015-01-02 00:00:02.500 -74.189805 -135.032069  6.844352e+06 -0.531154
# 2015-01-02 00:00:03.500 -74.252664 -134.996392  6.844353e+06 -0.372390
# 2015-01-02 00:00:04.500 -74.315515 -134.960404  6.844354e+06 -0.250209
#
#                          IRC_Error       FAC  FAC_Error  Flags     Flags_F  \
# 2015-01-02 00:00:00.500   0.042043 -0.883094   0.043680    0.0  22222224.0
# 2015-01-02 00:00:01.500   0.042202 -0.721999   0.043844    0.0  22222224.0
# 2015-01-02 00:00:02.500   0.042362 -0.551803   0.044009    0.0  22222224.0
# 2015-01-02 00:00:03.500   0.042523 -0.386855   0.044175    0.0  22222224.0
# 2015-01-02 00:00:04.500   0.042686 -0.259921   0.044342    0.0  22222224.0
#
#                          Flags_B  Flags_q  Orbit_nr  Hemisphere
# ...

# %%
my.add_apex_coords(DNS,date = 'none', h = 450)
my.add_heading(DNS, latitude = 'mLatitude' )

# %%
mOrbit_nr = np.cumsum(np.append(0, abs(np.diff(DNS.N_heading.values))))/4

# %%
plt.figure()

plt.plot(np.array(range(len(DNS.Orbit_nr.values))),DNS.Orbit_nr.values)
plt.plot(np.array(range(len(DNS.Orbit_nr.values))),mOrbit_nr)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
start_orbit=450

N = 100

fig_index = np.arange(90,-90,-0.5)

fig_orbit = np.array(range(N))/2+start_orbit

fig_values = np.zeros([len(fig_index),len(fig_orbit)])

for i in range(N):
    data_column = DNS[abs(mOrbit_nr-start_orbit+i/2)<0.01]
    data_column = data_column.set_index('mLatitude')
    fig_values[:,i] = data_column.reindex(labels=fig_index, method='nearest', tolerance=1).Density.values

# %%
plt.figure()

plt.imshow(fig_values, extent=[0, 5, 0, 5], origin='lower',
           cmap='jet')
plt.colorbar()
plt.axis(aspect='image')
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0.0, 5.0, 0.0, 5.0)

# %%
len(fig_values
# Out:
# 0
