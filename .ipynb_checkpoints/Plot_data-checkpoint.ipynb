# %% [markdown]
# # Plot grafs
# Import functions and load data

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
#from mpl_toolkits.basemap import Basemap
from scipy import signal
from datetime import datetime
import My_functions_v2 as my
IPython_default = plt.rcParams.copy()

# %%
import seaborn as sns
sns.set()

# %%
plt.rcParams.update({'font.size': 16})

# %% [markdown]
# ## Data

# %%
FAC = pd.read_pickle('/home/simon/Desktop/Bachelor_project/data/pkl_files/FAC_dual.pkl')
FAC = my.add_NaN_gap(FAC)

# %%
DNS = pd.read_pickle('/home/simon/Desktop/Bachelor_project/data/pkl_files/DNS.pkl')
DNS = my.add_NaN_gap(DNS)

# %% [markdown]
# ## Plot initial

# %%
plt.rcParams.update({'font.size': 12})
fig = plt.figure( figsize=(7,5 ))
width = 0.8
height = 0.8
ax2 = fig.add_axes([0.1, height/2+0.15, width, height/2],xticklabels=[],ylabel='$\mu A / m^2$')
ax3 = fig.add_axes([0.1, 0.1, width, height/2],ylabel=' kg$/ m^3$',xlabel='Date')
                   

ax2.plot(FAC.index.values,FAC.FAC.values,color=sns.color_palette()[1],label='FAC')
ax3.plot(DNS.index.values,DNS.Density.values,color=sns.color_palette()[2],label='Density')

ax3.annotate("St. Patrick's day storm", xy=(datetime(2015, 3,19), 3*10**-12),  xycoords='data',
            xytext=(datetime(2015, 4,5), 4.2*10**-12), textcoords='data',
            arrowprops=dict(arrowstyle="->"))


ax2.legend(loc=2)
ax3.legend(loc=2)
plt.savefig('/home/simon/Desktop/Bachelor_project/figures/from_code/initial_data.jpg')

# %% [markdown]
# ### plot Filter FAC

# %%
Flag_idx = (FAC.Flags_q>440404) | (FAC.Flags_B>10002)
filter_fac = FAC.FAC.copy().values
filter_fac[Flag_idx] = float('Nan')

# %%
plt.figure( figsize=(7,5 ))

plt.plot(FAC.index.values,filter_fac,color=sns.color_palette()[1],label='FAC')
plt.scatter(FAC[(FAC.Flags_q>440404)].index.values,FAC[(FAC.Flags_q>440404)].FAC.values,marker='+', 
            color=sns.color_palette()[3],label='q Flags',alpha=0.7)
plt.scatter(FAC[(FAC.Flags_B>10002)].index.values,FAC[(FAC.Flags_B>10002)].FAC.values, marker='x',
            color=sns.color_palette()[4],label='B Flags',alpha=0.7)

plt.legend(loc=2)
plt.ylabel('$\mu$A/$m^2$')
plt.xlabel('Date')
plt.savefig('/home/simon/Desktop/Bachelor_project/figures/from_code/FAC_flags.jpg')

# %%
plt.rcParams.update({'font.size': 16})
fig, ax = plt.subplots(figsize=(7,5 ))

ax.plot(FAC.index.values,filter_fac,color=sns.color_palette()[1],label='FAC')
ax.scatter(FAC[(FAC.Flags_q>440404)].index.values,FAC[(FAC.Flags_q>440404)].FAC.values,marker='+', 
            color=sns.color_palette()[3],label='q Flags',alpha=0.8)
ax.scatter(FAC[(FAC.Flags_B>10002)].index.values,FAC[(FAC.Flags_B>10002)].FAC.values, marker='x',
            color=sns.color_palette()[4],label='B Flags',alpha=0.8)

ax.annotate("Flagged Outliers", xy=(datetime(2015, 3,7,22,57), 100),  xycoords='data',
            xytext=(datetime(2015, 3,7,23,2),130), textcoords='data', ha='center',
            arrowprops=dict(arrowstyle="->"))

ax.annotate("", xy=(datetime(2015, 3,7,23,15), 5),  xycoords='data',
            xytext=(datetime(2015, 3,7,23,11),22), textcoords='data', ha='center',
            arrowprops=dict(arrowstyle="->"))

ax.annotate("Normal Measurements", xy=(datetime(2015, 3,7,23,5), 5),  xycoords='data',
            xytext=(datetime(2015, 3,7,23,10),25), textcoords='data', ha='center',
            arrowprops=dict(arrowstyle="->"))
ax.legend()
ax.set_ylabel('$\mu$A/$m^2$')
ax.set_xlabel('Date')
ax.set_xlim([datetime(2015, 3,7,22,50), datetime(2015, 3, 7,23,20)])
ax.set_ylim([-10, 200])
plt.savefig('/home/simon/Desktop/Bachelor_project/figures/from_code/FAC_flags_zoomed.jpg')

# %%
FAC_filter = pd.read_pickle('/home/simon/Desktop/Bachelor_project/data/pkl_files/FAC_filter.pkl')
FAC_filter = my.add_NaN_gap(FAC_filter)

# %%
plt.rcParams.update({'font.size': 16})
fig, ax = plt.subplots(figsize=(7,5 ))

ax.plot(FAC_filter.index.values,FAC_filter.FAC.values,color=sns.color_palette()[1],label='FAC')

ax.annotate("St. Patrick's day storm", xy=(datetime(2015, 3,17), 10),  xycoords='data',
            xytext=(datetime(2015, 1,11), 14), textcoords='data',
            arrowprops=dict(arrowstyle="->"))

ax.legend()
ax.set_ylabel('$\mu$A/$m^2$')
ax.set_xlabel('Date')

plt.savefig('/home/simon/Desktop/Bachelor_project/figures/from_code/FAC_filter.jpg')

# %% [markdown]
# ### Normalization Factors

# %%
DNS=DNS.dropna(how='any')
nFactors = np.genfromtxt('/home/simon/Desktop/Bachelor_project/data/normalization_factors.csv', delimiter=',')
omni = pd.read_pickle('/home/simon/Desktop/Bachelor_project/data/pkl_files/omni.pkl')
omni = omni.reindex(DNS.index,method='ffill')

# %%
plt.rcParams.update({'font.size': 12})
solar = (omni.F10_INDEX.values+omni.F10_Mean.values)/2

fig = plt.figure( figsize=(7,5 ))
width = 0.8
height = 0.8
ax2 = fig.add_axes([0.1, height/2+0.2, width, height/2],xlabel='Altitude (km)') #$(\text{F}_{10.7}+\Bar{\text{F}}_{10.7})/2$
ax3 = fig.add_axes([0.1, 0.1, width, height/2],xlabel='$[F_{10.7}+mean({F}_{10.7})]/2$')
                   

ax2.scatter(DNS.Altitude.values/1000,nFactors[:,0],color=sns.color_palette()[1],label='Altitude factor',marker='x')
ax3.scatter(solar, nFactors[:,1],color=sns.color_palette()[2],label='Solar activity factor',marker='x')


ax2.legend(loc=9)
ax3.legend(loc=9)
ax2.set_title('Density Normalization Factors')
plt.savefig('/home/simon/Desktop/Bachelor_project/figures/from_code/Normalization_factors.jpg')

# %% [markdown]
# ### plot Half orbit means

# %%
Half_orbit = pd.read_pickle('/home/simon/Desktop/Bachelor_project/data/pkl_files/half_orbit_means.pkl')
Half_orbit  = my.add_NaN_gap(Half_orbit )

# %%
Half_orbit.head()
# Out:
#                      Density_norm       FAC  FAC_power       Density  \
# 2015-01-02 00:50:50  5.932167e-13  0.104478   0.284759  6.468488e-13
# 2015-01-02 01:37:45  7.720531e-13  0.139248   0.372618  6.987142e-13
# 2015-01-02 02:24:40  5.577984e-13  0.113231   0.390340  6.089699e-13
# 2015-01-02 03:11:35  7.597623e-13  0.181961   0.565810  6.858343e-13
# 2015-01-02 03:58:30  5.691719e-13  0.075313   0.165567  6.237317e-13
#
#                           Altitude  Orbit_nr  Hemisphere  AP_INDEX   Kp  \
# 2015-01-02 00:50:50  464222.287865       1.0         1.0      15.0  3.0
# 2015-01-02 01:37:45  475492.964700       1.0        -1.0      15.0  3.0
# 2015-01-02 02:24:40  464224.157119       2.0         1.0      15.0  3.0
# 2015-01-02 03:11:35  475506.057772       2.0        -1.0       4.0  1.0
# 2015-01-02 03:58:30  464035.397442       3.0         1.0       4.0  1.0
#
#                      F10_INDEX  BY_GSM  BZ_GSM  Bulk_speed    F10_Mean  \
# 2015-01-02 00:50:50      141.0    -1.0    -2.1       433.0  129.029218
# 2015-01-02 01:37:45      141.0    -0.6    -1.7       433.0  129.032511
# 2015-01-02 02:24:40      141.0    -2.2    -2.4       434.0  129.035803
# 2015-01-02 03:11:35      141.0    -3.0    -2.3       433.0  129.039095
# 2015-01-02 03:58:30      141.0    -3.0    -2.3       433.0  129.039095
#
#                        PyAmps
# 2015-01-02 00:50:50  1.769016
# 2015-01-02 01:37:45  2.962752
# 2015-01-02 02:24:40  1.880936
# 2015-01-02 03:11:35  4.111182
# 2015-01-02 03:58:30  1.841245

# %%
plt.rcParams.update({'font.size': 12})
fig = plt.figure( figsize=(7,5 ))
width = 0.8
height = 0.8
ax2 = fig.add_axes([0.1, height/2+0.15, width, height/2],xticklabels=[],ylabel='$\mu A / m^2$')
ax3 = fig.add_axes([0.1, 0.1, width, height/2],ylabel=' kg$/ m^3$',xlabel='Date')
                   

ax2.plot(Half_orbit.index.values,Half_orbit.FAC.values,color=sns.color_palette()[1],label='FAC')
#ax2.plot(Half_orbit.index.values,Half_orbit.FAC_power.values,color=sns.color_palette()[0],label='RMS FAC')

ax2.annotate("St. Patrick's day storm", xy=(datetime(2015, 3,17), 0.5),  xycoords='data',
             xytext=(datetime(2015, 1,15),0.6), textcoords='data',
             arrowprops=dict(arrowstyle="->"))

#ax3.plot(Half_orbit.index.values,Half_orbit.Density.values,color=sns.color_palette()[2],label='Density')
ax3.plot(Half_orbit.index.values,Half_orbit.Density_norm.values,color=sns.color_palette()[2],label='Normalized Density')

ax3.annotate("St. Patrick's day storm", xy=(datetime(2015, 3,17), 2*10**-12),  xycoords='data',
             xytext=(datetime(2015, 1,15), 2.3*10**-12), textcoords='data',
             arrowprops=dict(arrowstyle="->"))


ax2.legend(loc=1)
ax3.legend(loc=1)

plt.savefig('/home/simon/Desktop/Bachelor_project/figures/from_code/Half_orbit.jpg')

# %%
plt.rcParams.update({'font.size': 12})
fig = plt.figure( figsize=(7,5 ))
width = 0.8
height = 0.8
ax1 = fig.add_axes([0.1, 0.7, width, 0.25],xticklabels=[],ylabel='$a_p$')
ax2 = fig.add_axes([0.1, 0.4, width, 0.25],xticklabels=[],ylabel='$\mu A / m^2$')
ax3 = fig.add_axes([0.1, 0.1, width, 0.25],ylabel=' kg$/ m^3$',xlabel='Date')
                   
ax1.plot(Half_orbit.index.values,Half_orbit.AP_INDEX.values,color=sns.color_palette()[0],label='$a_p$',drawstyle='steps')
#ax2.plot(Half_orbit.index.values,Half_orbit.FAC_power.values,color=sns.color_palette()[0],label='RMS FAC')

ax2.plot(Half_orbit.index.values,Half_orbit.FAC.values,color=sns.color_palette()[1],label='FAC')
#ax2.plot(Half_orbit.index.values,Half_orbit.FAC_power.values,color=sns.color_palette()[0],label='RMS FAC')

#ax3.plot(Half_orbit.index.values,Half_orbit.Density.values,color=sns.color_palette()[2],label='Density')
ax3.plot(Half_orbit.index.values,Half_orbit.Density_norm.values,color=sns.color_palette()[2],label='Normalized Density')

#ax3.annotate("St. Patrick's day storm", xy=(datetime(2015, 3,19), 3*10**-12),  xycoords='data',
#            xytext=(datetime(2015, 4,5), 4.2*10**-12), textcoords='data',
#            arrowprops=dict(arrowstyle="->"))


ax1.legend(loc=2)
ax2.legend(loc=2)
ax3.legend(loc=2)
ax1.set_xlim([datetime(2015, 3,16,20,0), datetime(2015, 3,19,1,0)])
ax2.set_xlim([datetime(2015, 3,16,20,0), datetime(2015, 3,19,1,0)])
ax3.set_xlim([datetime(2015, 3,16,20,0), datetime(2015, 3,19,1,0)])

plt.savefig('/home/simon/Desktop/Bachelor_project/figures/from_code/Half_orbit_storm.jpg')

# %%
plt.rcParams.update({'font.size': 12})
fig = plt.figure( figsize=(7,5 ))
width = 0.8
height = 0.8
ax2 = fig.add_axes([0.1, height/2+0.15, width, height/2],xticklabels=[],ylabel='$\mu A / m^2$')
ax3 = fig.add_axes([0.1, 0.1, width, height/2],ylabel=' kg$/ m^3$',xlabel='Date')
                   

ax2.plot(Half_orbit[Half_orbit.Hemisphere==1].index.values,Half_orbit[Half_orbit.Hemisphere==1].FAC.values,color=sns.color_palette()[1],label='FAC')
#ax2.plot(Half_orbit.index.values,Half_orbit.FAC_power.values,color=sns.color_palette()[0],label='RMS FAC')

#ax3.plot(Half_orbit.index.values,Half_orbit.Density.values,color=sns.color_palette()[2],label='Density')
ax3.plot(Half_orbit[Half_orbit.Hemisphere==1].index.values,Half_orbit[Half_orbit.Hemisphere==1].Density_norm.values,color=sns.color_palette()[2],label='Normalized Density')

#ax3.annotate("St. Patrick's day storm", xy=(datetime(2015, 3,19), 3*10**-12),  xycoords='data',
#            xytext=(datetime(2015, 4,5), 4.2*10**-12), textcoords='data',
#            arrowprops=dict(arrowstyle="->"))


ax2.legend(loc=2)
ax3.legend(loc=2)
ax2.set_xlim([datetime(2015, 3,16,20,0), datetime(2015, 3,19,1,0)])
ax3.set_xlim([datetime(2015, 3,16,20,0), datetime(2015, 3,19,1,0)])

plt.savefig('/home/simon/Desktop/Bachelor_project/figures/from_code/Half_orbit_storm_S.jpg')

# %%
plt.rcParams.update({'font.size': 12})
fig = plt.figure( figsize=(7,5 ))
width = 0.8
height = 0.8
ax2 = fig.add_axes([0.1, height/2+0.15, width, height/2],xticklabels=[],ylabel='$\mu A / m^2$')
ax3 = fig.add_axes([0.1, 0.1, width, height/2],ylabel=' kg$/ m^3$',xlabel='Date')
                   

ax2.plot(Half_orbit[Half_orbit.Hemisphere==-1].index.values,Half_orbit[Half_orbit.Hemisphere==-1].FAC.values,color=sns.color_palette()[1],label='FAC')
#ax2.plot(Half_orbit.index.values,Half_orbit.FAC_power.values,color=sns.color_palette()[0],label='RMS FAC')

#ax3.plot(Half_orbit.index.values,Half_orbit.Density.values,color=sns.color_palette()[2],label='Density')
ax3.plot(Half_orbit[Half_orbit.Hemisphere==-1].index.values,Half_orbit[Half_orbit.Hemisphere==-1].Density_norm.values,color=sns.color_palette()[2],label='Normalized Density')

#ax3.annotate("St. Patrick's day storm", xy=(datetime(2015, 3,19), 3*10**-12),  xycoords='data',
#            xytext=(datetime(2015, 4,5), 4.2*10**-12), textcoords='data',
#            arrowprops=dict(arrowstyle="->"))


ax2.legend(loc=2)
ax3.legend(loc=2)
ax2.set_xlim([datetime(2015, 3,16,20,0), datetime(2015, 3,19,1,0)])
ax3.set_xlim([datetime(2015, 3,16,20,0), datetime(2015, 3,19,1,0)])

plt.savefig('/home/simon/Desktop/Bachelor_project/figures/from_code/Half_orbit_storm_S.jpg')

# %% [markdown]
# ### Colormap plot

# %%
DNS = pd.read_pickle('/home/simon/Desktop/Bachelor_project/data/pkl_files/DNS_normalized.pkl')
FAC = pd.read_pickle('/home/simon/Desktop/Bachelor_project/data/pkl_files/FAC_filter.pkl')

# %%
plt.rcParams.update(IPython_default);

# %%
DNS_Z,DNS_index,DNS_dates,DNS_orbit = my.Color_map(DNS,'2015-03-15-02',61,'mLatitude')

# %%
plt.figure()

# Formate the dates to a string
fig_date_str = DNS_dates.strftime('%d/%m %Hh')

# Plot the data
plt.imshow(np.log10(DNS_Z), extent=[0, 5, 0, 5], aspect='equal', origin='lower',
           cmap='jet')
bar = plt.colorbar()
bar.set_label('$\log_{10}$(kg$/ m^3$)')
# Set the ticks and labels...
# Create x labes
x_labels = fig_date_str[::20]
x_ticks = np.linspace(0,5-((len(fig_date_str)-1)%20)/len(fig_date_str)*5,len(x_labels))
plt.xticks(x_ticks, x_labels)
plt.xlabel('Date')

# Create y labes
y_labels = [-90,-45,0,45,90,45,0,-45,-90]
y_ticks = np.linspace(0,5,len(y_labels))
plt.yticks(y_ticks, y_labels)
plt.ylabel('Magnetic Latitude')


plt.title('Density')
plt.savefig('/home/simon/Desktop/Bachelor_project/figures/from_code/Color_map_Density.jpg',dpi=200)

# %%
FAC_Z,FAC_index,FAC_dates,FAC_orbit = my.Color_map(FAC,'2015-03-15-02',61,'mLatitude',30,'20s',100)

# %%
fig, ax = plt.subplots()

fig_date_str = FAC_dates.strftime('%d/%m %Hh')

plt.imshow(FAC_Z, extent=[0, 5, 0, 5], origin='lower',
           cmap='jet')
#cmap='seismic')
bar = plt.colorbar()
bar.set_label('$\mu A / m^2$')
# Set the ticks and labels...
x_labels = fig_date_str[::20]
x_ticks = np.linspace(0,5-((len(fig_date_str)-1)%20)/len(fig_date_str)*5,len(x_labels))
plt.xticks(x_ticks, x_labels)
plt.xlabel('Date')

y_ticks = np.linspace(0,5,9)
y_labels = [-90,-60,'$\pm$ 30',60,90,60,'$\pm$ 30',-60,-90]
plt.yticks(y_ticks, y_labels)
plt.ylabel('Magnetic Latitude')


plt.title('FAC')
plt.savefig('/home/simon/Desktop/Bachelor_project/figures/from_code/Color_map_FAC.jpg',dpi=200)

# %% [markdown]
# ## Histograms

# %%
sns.set()
Half_orbit = pd.read_pickle('/home/simon/Desktop/Bachelor_project/data/pkl_files/half_orbit_means.pkl')

# %% [markdown]
# #### ALL data

# %%
active = Half_orbit[Half_orbit.Kp >= 4]
quiet =  Half_orbit[Half_orbit.Kp < 4]

# %%
g.annotate?

# %%
ylim = [Half_orbit.Density_norm.min()*0.9*10**12,Half_orbit.Density_norm.max()*1.1*10**12]
g = sns.jointplot(Half_orbit.FAC.values,Half_orbit.Density_norm.values*10**12, ylim= ylim);

g.set_axis_labels("FAC ($\mu A / m^2$)", "Density($ kg/ m^3$) X $10^{-12}$")
plt.savefig('/home/simon/Desktop/Bachelor_project/figures/from_code/Histogram_FAC_Dens_all.jpg',dpi=200)

# %%
# Not to be used 
ylim = [Half_orbit.Density.min()*0.9*10**12,Half_orbit.Density.max()*1.1*10**12]
g = sns.jointplot(Half_orbit.FAC.values,Half_orbit.Density.values*10**12, ylim= ylim);

g.set_axis_labels("FAC ($\mu A / m^2$)", "Density($ kg/ m^3$) X $10^{-12}$")
plt.title('Not NORMAlized')
# Out:
# Text(0.5,1,'Not NORMAlized')

# %%
ylim = [Half_orbit.Density_norm.min()*0.9*10**12,Half_orbit.Density_norm.max()*1.1*10**12]
g = sns.jointplot(Half_orbit.AP_INDEX.values,Half_orbit.Density_norm.values*10**12, ylim= ylim);

g.set_axis_labels("ap", "Density($ kg/ m^3$) X $10^{-12}$")
plt.savefig('/home/simon/Desktop/Bachelor_project/figures/from_code/Histogram_ap_Dens_all.jpg',dpi=200)

# %%
# Not to be used 
ylim = [Half_orbit.Density.min()*0.9*10**12,Half_orbit.Density.max()*1.1*10**12]
g = sns.jointplot(Half_orbit.AP_INDEX.values,Half_orbit.Density.values*10**12, ylim= ylim);

g.set_axis_labels("ap", "Density($ kg/ m^3$) X $10^{-12}$")
plt.title('Not NORMAlized')
# Out:
# Text(0.5,1,'Not NORMAlized')

# %% [markdown]
# ### Active

# %%
ylim = [Half_orbit.Density_norm.min()*0.9*10**12,Half_orbit.Density_norm.max()*1.1*10**12]
g = sns.jointplot(active.FAC.values,active.Density_norm.values*10**12, ylim= ylim);

g.set_axis_labels("FAC ($\mu A / m^2$)", "Density($ kg/ m^3$) X $10^{-12}$")
plt.savefig('/home/simon/Desktop/Bachelor_project/figures/from_code/Histogram_FAC_Dens_active.jpg',dpi=200)

# %%
ylim = [Half_orbit.Density_norm.min()*0.9*10**12,Half_orbit.Density_norm.max()*1.1*10**12]
g = sns.jointplot(active.AP_INDEX.values,active.Density_norm.values*10**12, ylim= ylim);

g.set_axis_labels("ap", "Density($ kg/ m^3$) X $10^{-12}$")
plt.savefig('/home/simon/Desktop/Bachelor_project/figures/from_code/Histogram_ap_Dens_active.jpg',dpi=200)

# %% [markdown]
# ### interesting points

# %%
print('Interesting points')
p1 = Half_orbit[(Half_orbit.Density_norm<1.5*10**-12) &(Half_orbit.FAC>0.6)].index[0].to_pydatetime()
p2 = Half_orbit[(Half_orbit.Density_norm>2.5*10**-12) &(Half_orbit.FAC<0.3)].index[0].to_pydatetime()

print(p1)
print(p2)
# Out:
# Interesting points
# 2015-01-07 09:49:55
# 2015-03-17 19:54:40

# %%
plot_val = Half_orbit[datetime(2015, 1,7,1,0):datetime(2015, 1,7,23,0)]

plt.rcParams.update({'font.size': 12})
fig = plt.figure( figsize=(7,5 ))
width = 0.8
height = 0.8
ax2 = fig.add_axes([0.1, height/2+0.15, width, height/2],xticklabels=[],ylabel='$\mu A / m^2$')
ax3 = fig.add_axes([0.1, 0.1, width, height/2],ylabel=' kg$/ m^3$',xlabel='Date')


ax2.plot(plot_val.index.values,plot_val.FAC.values,color=sns.color_palette()[1],label='FAC')
#ax2.plot(Half_orbit.index.values,Half_orbit.FAC_power.values,color=sns.color_palette()[0],label='RMS FAC')

ax2.annotate("$p_1$", xy=(datetime(2015, 1,7,9,40), 0.68),  xycoords='data',
            xytext=(datetime(2015, 1,7,7,40), 0.6), textcoords='data',
            arrowprops=dict(arrowstyle="->"))

#ax3.plot(Half_orbit.index.values,Half_orbit.Density.values,color=sns.color_palette()[2],label='Density')
ax3.plot(plot_val.index.values,plot_val.Density_norm.values,color=sns.color_palette()[2],label='Normalized Density')

ax3.annotate("$p_1$", xy=(datetime(2015, 1,7,9,40), 1.4*10**-12),  xycoords='data',
            xytext=(datetime(2015, 1,7,7,40), 1.45*10**-12), textcoords='data',
            arrowprops=dict(arrowstyle="->"))


ax2.legend(loc=1)
ax3.legend(loc=1)


plt.savefig('/home/simon/Desktop/Bachelor_project/figures/from_code/point1.jpg')

# %%
plt.rcParams.update({'font.size': 12})
fig = plt.figure( figsize=(7,5 ))
width = 0.8
height = 0.8
ax2 = fig.add_axes([0.1, height/2+0.15, width, height/2],xticklabels=[],ylabel='$\mu A / m^2$')
ax3 = fig.add_axes([0.1, 0.1, width, height/2],ylabel=' kg$/ m^3$',xlabel='Date')
     
ax2.plot(Half_orbit.index.values,Half_orbit.FAC.values,color=sns.color_palette()[1],label='FAC')
#ax2.plot(Half_orbit.index.values,Half_orbit.FAC_power.values,color=sns.color_palette()[0],label='RMS FAC')

ax2.annotate("$p_2$", xy=(datetime(2015, 3,17,19,30), 0.25),  xycoords='data',
            xytext=(datetime(2015, 3,17,15,30), 0.2), textcoords='data',
            arrowprops=dict(arrowstyle="->"))

#ax3.plot(Half_orbit.index.values,Half_orbit.Density.values,color=sns.color_palette()[2],label='Density')
ax3.plot(Half_orbit.index.values,Half_orbit.Density_norm.values,color=sns.color_palette()[2],label='Normalized Density')

ax3.annotate("$p_2$", xy=(datetime(2015, 3,17,20), 2.4*10**-12),  xycoords='data',
            xytext=(datetime(2015, 3,17,19,30), 1.8*10**-12), textcoords='data',
            arrowprops=dict(arrowstyle="->"))


ax2.legend(loc=1)
ax3.legend(loc=1)
ax2.set_xlim([datetime(2015, 3,16,20,0), datetime(2015, 3,19,1,0)])
ax3.set_xlim([datetime(2015, 3,16,20,0), datetime(2015, 3,19,1,0)])

plt.savefig('/home/simon/Desktop/Bachelor_project/figures/from_code/point2.jpg')

# %% [markdown]
# ## Correlation

# %%
var2=['FAC','FAC_power','PyAmps','Kp','AP_INDEX']
corr ,N,lag,dt = my.correlation(Half_orbit,'Density_norm',var2,minlag = -5,maxlag = 15)

# %%
fig, ax = plt.subplots(figsize=(7,5 ))
plt.plot(lag/2,corr[0,:],color=sns.color_palette()[1],label='FAC')

plt.plot(lag/2,corr[1,:],color=sns.color_palette()[3],label='RMS FAC')
plt.plot(lag/2,corr[2,:],color=sns.color_palette()[4],label='PyAmps')
plt.plot(lag/2,corr[3,:],color=sns.color_palette()[5],label='Kp')
plt.plot(lag/2,corr[4,:],color=sns.color_palette()[0],label='ap')

ax.set_ylabel('Correlation')
ax.set_xlabel('Lag (Orbital periods)')

plt.legend()
plt.savefig('/home/simon/Desktop/Bachelor_project/figures/from_code/correlation.jpg')

# %%
dt[lag==2],dt[lag==8]
# Out:
# (array([1.56254051]), array([6.25015664]))

# %% [markdown]
# Cira 72 uses a lag of 6.696 Hours

# %%
shift2_df,dt=my.shift_time(Half_orbit,'Density_norm',var2,4)

# %%
ylim = [shift2_df.Density_norm.min()*0.9*10**12,shift2_df.Density_norm.max()*1.1*10**12]
g = sns.jointplot(shift2_df.FAC.values,shift2_df.Density_norm.values*10**12, ylim= ylim);

g.set_axis_labels("FAC ($\mu A / m^2$)", "Density($ kg/ m^3$) X $10^{-12}$")
plt.savefig('/home/simon/Desktop/Bachelor_project/figures/from_code/Histogram_FAC_Dens_all_lag2orbit.jpg',dpi=200)

# %%
ylim = [shift2_df.Density_norm.min()*0.9*10**12,shift2_df.Density_norm.max()*1.1*10**12]
g = sns.jointplot(shift2_df.AP_INDEX.values,shift2_df.Density_norm.values*10**12, ylim= ylim);

g.set_axis_labels("ap", "Density($ kg/ m^3$) X $10^{-12}$")
plt.savefig('/home/simon/Desktop/Bachelor_project/figures/from_code/Histogram_ap_Dens_all_lag2orbit.jpg',dpi=200)

# %% [markdown]
# ## PyAmps

# %%
Half_orbit  = my.add_NaN_gap(Half_orbit )

# %%
plt.rcParams.update({'font.size': 12})
fig = plt.figure( figsize=(7,5 ))
width = 0.8
height = 0.8
ax1 = fig.add_axes([0.1, 0.7, width, 0.25],xticklabels=[],ylabel='$\mu A / m^2$')
ax2 = fig.add_axes([0.1, 0.4, width, 0.25],xticklabels=[],ylabel='$\mu A / m^2$')
ax3 = fig.add_axes([0.1, 0.1, width, 0.25],ylabel='$MA$',xlabel='Date')
                   
ax1.plot(Half_orbit.index.values,Half_orbit.FAC.values,color=sns.color_palette()[1],label='FAC')
#ax2.plot(Half_orbit.index.values,Half_orbit.FAC_power.values,color=sns.color_palette()[0],label='RMS FAC')

ax2.plot(Half_orbit.index.values,Half_orbit.FAC_power.values,color=sns.color_palette()[3],label='RMS FAC')
#ax2.plot(Half_orbit.index.values,Half_orbit.FAC_power.values,color=sns.color_palette()[0],label='RMS FAC')

#ax3.plot(Half_orbit.index.values,Half_orbit.Density.values,color=sns.color_palette()[2],label='Density')
ax3.plot(Half_orbit.index.values,Half_orbit.PyAmps.values,color=sns.color_palette()[2],label='PyAmps')

#ax3.annotate("St. Patrick's day storm", xy=(datetime(2015, 3,19), 3*10**-12),  xycoords='data',
#            xytext=(datetime(2015, 4,5), 4.2*10**-12), textcoords='data',
#            arrowprops=dict(arrowstyle="->"))


ax1.legend(loc=1)
ax2.legend(loc=1)
ax3.legend(loc=1)

plt.savefig('/home/simon/Desktop/Bachelor_project/figures/from_code/FAC_pyAmps.jpg')

# %%
from pyamps import AMPS
indx = Half_orbit.FAC==Half_orbit.FAC.max()

# %%
m = AMPS(Half_orbit[indx].Bulk_speed.values[0], # Solar wind velocity in km/s
         Half_orbit[indx].BY_GSM.values[0], # IMF By (GSM) in nT
         Half_orbit[indx].BZ_GSM.values[0], # IMF Bz (GSM) in nT,
         my.dipole_tilt_angle(Half_orbit[indx].index[0])/np.pi*180, # dipole tilt angle in degrees
         Half_orbit[indx].F10_INDEX.values[0], # F107_index
         height = 470 )

# %%
m.plot_currents(vector_scale=500)
plt.savefig('/home/simon/Desktop/Bachelor_project/figures/from_code/pyAmps_storm.jpg')

# %%
m.plot_currents?
