# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# %%
FAC = pd.read_pickle('/home/simon/Desktop/Bachelor_project/data/pkl_files/FAC_dual.pkl')

# %%
FAC_p = FAC['20150310':'20150320']
N_total=len(FAC)
odd_val = len(FAC[FAC.FAC>20])

# %%
FAC.head()
# Out:
#                           Latitude   Longitude        Radius       IRC  \
# 2015-01-02 00:00:00.500 -74.064067 -135.102502  6.844350e+06 -0.849996
# 2015-01-02 00:00:01.500 -74.126940 -135.067437  6.844351e+06 -0.694960
# 2015-01-02 00:00:02.500 -74.189805 -135.032069  6.844352e+06 -0.531154
# 2015-01-02 00:00:03.500 -74.252664 -134.996392  6.844353e+06 -0.372390
# 2015-01-02 00:00:04.500 -74.315515 -134.960404  6.844354e+06 -0.250209
#
#                          IRC_Error       FAC  FAC_Error  Flags     Flags_F  \
# 2015-01-02 00:00:00.500   0.042043 -0.883094   0.043680    0.0  22222224.0
# 2015-01-02 00:00:01.500   0.042202 -0.721999   0.043844    0.0  22222224.0
# 2015-01-02 00:00:02.500   0.042362 -0.551803   0.044009    0.0  22222224.0
# 2015-01-02 00:00:03.500   0.042523 -0.386855   0.044175    0.0  22222224.0
# 2015-01-02 00:00:04.500   0.042686 -0.259921   0.044342    0.0  22222224.0
#
#                          Flags_B  Flags_q  Orbit_nr  Hemisphere
# 2015-01-02 00:00:00.500      2.0    400.0       0.0        -1.0
# 2015-01-02 00:00:01.500      2.0    400.0       0.0        -1.0
# 2015-01-02 00:00:02.500      2.0    400.0       0.0        -1.0
# 2015-01-02 00:00:03.500      2.0    400.0       0.0        -1.0
# 2015-01-02 00:00:04.500      2.0    400.0       0.0        -1.0

# %% [markdown]
# ## Flags

# %%
plt.figure()

p1 = FAC_p.FAC.plot(legend=True)
p2 = FAC_p.Flags.plot(secondary_y=True, style='r',legend=True)
p1.set_ylabel('muA/m^2')
p1.right_ax.set_ylabel('kg/m^3')
plt.title('The inital data')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,'The inital data')

# %%
np.unique(FAC.Flags)
# Out:
# array([       0.,  1100000.,  2200000.,  3300000.,  4400000.])

# %%
flags = len(FAC[(FAC.Flags!=0)])
flag_odd = len(FAC[(FAC.Flags!=0)&(FAC.FAC>20)])

print("Flag observations is %d out off %d or %.2f procent" % (flags,N_total,flags/N_total*100))
print("Flaged odd values %d out off %d or %.2f procent" % (flag_odd,odd_val,flag_odd/odd_val*100))
# Out:
# Flag observations is 87160 out off 4287278 or 2.03 procent
# Flaged odd values 0 out off 639 or 0.00 procent

# %% [markdown]
# ## Flags_f

# %%
plt.figure()

p1 = FAC_p.FAC.plot(legend=True)
p2 = FAC_p.Flags_F.plot(secondary_y=True, style='r',legend=True)
p1.set_ylabel('muA/m^2')
p1.right_ax.set_ylabel('kg/m^3')
plt.title('The inital data')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,'The inital data')

# %%
np.unique(FAC.Flags_F)
# Out:
# array([ 22222224.,  22222234.,  22222244.,  22222324.,  22222334.,
#         22222344.,  22222424.,  22222444.,  22223224.,  22223234.,
#         22223244.,  22224224.,  22224234.,  22224244.,  22232224.,
#         22232234.,  22232244.,  22232324.,  22232344.,  22232424.,
#         22242224.,  22242324.,  22242424.,  22322224.,  22322244.,
#         22322324.,  22322344.,  22322424.,  22322444.,  22323224.,
#         22323234.,  22324224.,  22324234.,  22324244.,  22332224.,
#         22332244.,  22332324.,  22332344.,  22332424.,  22333224.,
#         22342224.,  22342324.,  22342424.,  22422424.,  22432244.,
#         22432324.,  22432424.,  22442324.,  22442424.,  33333334.,
#         33333344.,  33333434.,  33334334.,  33334344.,  33343334.,
#         33343434.,  33433434.,  33443434.,  44444444.])

# %%
flags = len(FAC[(FAC.Flags_F!=22222224)])
flag_odd = len(FAC[(FAC.Flags_F!=22222224)&(FAC.FAC>20)])

print("Flag observations is %d out off %d or %.2f procent" % (flags,N_total,flags/N_total*100))
print("Flaged odd values %d out off %d or %.2f procent" % (flag_odd,odd_val,flag_odd/odd_val*100))
# Out:
# Flag observations is 76271 out off 4287278 or 1.78 procent
# Flaged odd values 160 out off 639 or 25.04 procent

# %% [markdown]
# # Flags_B

# %%
plt.figure()

p1 = FAC_p.FAC.plot(legend=True)
p2 = FAC_p.Flags_B.plot(secondary_y=True, style='r',legend=True)
p1.set_ylabel('muA/m^2')
p1.right_ax.set_ylabel('kg/m^3')
plt.title('The inital data')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,'The inital data')

# %%
np.unique(FAC.Flags_B)
# Out:
# array([  2.00000000e+00,   1.20000000e+01,   2.20000000e+01,
#          3.20000000e+01,   4.20000000e+01,   1.02000000e+02,
#          1.00200000e+03,   1.02200000e+03,   1.04200000e+03,
#          2.00200000e+03,   1.00020000e+04,   1.11101130e+07,
#          1.11111120e+07,   1.11111130e+07,   1.11111220e+07,
#          1.11111230e+07,   1.11111420e+07,   1.11111430e+07,
#          1.11121130e+07,   1.11121430e+07,   2.22222220e+07,
#          2.22222240e+07,   2.22222320e+07,   2.22222420e+07,
#          2.22222440e+07,   3.33333330e+07,   3.33333430e+07,
#          3.33333440e+07,   4.44444440e+07])

# %%
flags = len(FAC[(FAC.Flags_B!=2)])
flag_odd = len(FAC[(FAC.Flags_B!=2)&(FAC.FAC>20)])

print("Flag observations is %d out off %d or %.2f procent" % (flags,N_total,flags/N_total*100))
print("Flaged odd values %d out off %d or %.2f procent" % (flag_odd,odd_val,flag_odd/odd_val*100))
# Out:
# Flag observations is 10384 out off 4287278 or 0.24 procent
# Flaged odd values 586 out off 639 or 91.71 procent

# %%
print(" hej \%")
# Out:
#  hej \%
