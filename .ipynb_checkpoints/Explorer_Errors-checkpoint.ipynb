# %% [markdown]
# # Flag investigation
#
# - Flags are probably digit coded
# - Scale magnetometer on Swam C is broken so it alwas produse an error code
# - Most effecient filtering is still the latitude
# - Consider to filter values near around Flaged values.

# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# %%
FAC = pd.read_pickle('/home/simon/Desktop/Bachelor_project/data/pkl_files/FAC_dual.pkl')

# %%
FAC = FAC[abs(FAC.Latitude)>40]

# %%
FAC_p = FAC['20150310':'20150320']
N_total=len(FAC)
odd_val = len(FAC[abs(FAC.FAC)>20])

# %%
FAC.head()
# Out:
#                           Latitude   Longitude        Radius       IRC  \
# 2015-01-02 00:00:00.500 -74.064067 -135.102502  6.844350e+06 -0.849996
# 2015-01-02 00:00:01.500 -74.126940 -135.067437  6.844351e+06 -0.694960
# 2015-01-02 00:00:02.500 -74.189805 -135.032069  6.844352e+06 -0.531154
# 2015-01-02 00:00:03.500 -74.252664 -134.996392  6.844353e+06 -0.372390
# 2015-01-02 00:00:04.500 -74.315515 -134.960404  6.844354e+06 -0.250209
#
#                          IRC_Error       FAC  FAC_Error  Flags     Flags_F  \
# 2015-01-02 00:00:00.500   0.042043 -0.883094   0.043680    0.0  22222224.0
# 2015-01-02 00:00:01.500   0.042202 -0.721999   0.043844    0.0  22222224.0
# 2015-01-02 00:00:02.500   0.042362 -0.551803   0.044009    0.0  22222224.0
# 2015-01-02 00:00:03.500   0.042523 -0.386855   0.044175    0.0  22222224.0
# 2015-01-02 00:00:04.500   0.042686 -0.259921   0.044342    0.0  22222224.0
#
#                          Flags_B  Flags_q  Orbit_nr  Hemisphere
# 2015-01-02 00:00:00.500      2.0    400.0       0.0        -1.0
# 2015-01-02 00:00:01.500      2.0    400.0       0.0        -1.0
# 2015-01-02 00:00:02.500      2.0    400.0       0.0        -1.0
# 2015-01-02 00:00:03.500      2.0    400.0       0.0        -1.0
# 2015-01-02 00:00:04.500      2.0    400.0       0.0        -1.0

# %% [markdown]
# ## Flags

# %%
np.unique(FAC.Flags)
# Out:
# array([       0.,  1100000.,  2200000.,  3300000.,  4400000.])

# %%
flags = len(FAC[(FAC.Flags!=0)])
flag_odd = len(FAC[(FAC.Flags!=0)&(abs(FAC.FAC)>20)])

print("Flag observations is %d out off %d or %.2f procent" % (flags,N_total,flags/N_total*100))
print("Flaged odd values %d out off %d or %.2f procent" % (flag_odd,odd_val,flag_odd/odd_val*100))
# Out:
# Flag observations is 57089 out off 2793344 or 2.04 procent
# Flaged odd values 0 out off 116 or 0.00 procent

# %% [markdown]
# ## Flags_f

# %%
np.unique(FAC.Flags_F)
# Out:
# array([ 22222224.,  22222234.,  22222244.,  22222324.,  22222424.,
#         22223224.,  22223234.,  22223244.,  22224224.,  22224244.,
#         22232224.,  22232234.,  22232244.,  22232324.,  22232424.,
#         22242224.,  22242324.,  22242424.,  22322224.,  22322244.,
#         22322324.,  22322424.,  22323224.,  22323234.,  22324224.,
#         22324234.,  22332224.,  22332324.,  22332424.,  22342224.,
#         22342324.,  22342424.,  22422424.,  22432324.,  22432424.,
#         22442324.,  22442424.,  33333334.,  33333434.,  33334344.,
#         33343334.,  33343434.,  33433434.,  33443434.,  44444444.])

# %%
flags = len(FAC[(FAC.Flags_F!=22222224)])
flag_odd = len(FAC[(FAC.Flags_F!=22222224)&(abs(FAC.FAC)>20)])

print("Flag observations is %d out off %d or %.2f procent" % (flags,N_total,flags/N_total*100))
print("Flaged odd values %d out off %d or %.2f procent" % (flag_odd,odd_val,flag_odd/odd_val*100))
# Out:
# Flag observations is 48787 out off 2793344 or 1.75 procent
# Flaged odd values 88 out off 116 or 75.86 procent

# %%
flags_codes = np.unique(FAC.Flags_F).astype('int32')
obs_remove = np.zeros(len(flags_codes))
odd_remove = np.zeros(len(flags_codes))
obs_remove[0] = len(FAC[(FAC.Flags_F>flags_codes[0])])
odd_remove[0] = len(FAC[(FAC.Flags_F>flags_codes[0])&(abs(FAC.FAC)>20)])

for i in range(1,len(flags_codes)):
    obs_remove[i] = len(FAC[(FAC.Flags_F>flags_codes[i])])
    odd_remove[i] = len(FAC[(FAC.Flags_F>flags_codes[i])&(abs(FAC.FAC)>20)])
    n = obs_remove[i-1]-obs_remove[i]
    n_odd = odd_remove[i-1]-odd_remove[i]
    print("%d values are flaged with %d and %.2f procent of those are outliers" % (n,flags_codes[i],n_odd/n*100))
# Out:
# 727 values are flaged with 22222234 and 0.00 procent of those are outliers
# 43501 values are flaged with 22222244 and 0.00 procent of those are outliers
# 620 values are flaged with 22222324 and 0.00 procent of those are outliers
# 57 values are flaged with 22222424 and 0.00 procent of those are outliers
# 33 values are flaged with 22223224 and 6.06 procent of those are outliers
# 3 values are flaged with 22223234 and 33.33 procent of those are outliers
# 5 values are flaged with 22223244 and 60.00 procent of those are outliers
# 6 values are flaged with 22224224 and 0.00 procent of those are outliers
# 3 values are flaged with 22224244 and 100.00 procent of those are outliers
# 2640 values are flaged with 22232224 and 1.25 procent of those are outliers
# 3 values are flaged with 22232234 and 0.00 procent of those are outliers
# 12 values are flaged with 22232244 and 0.00 procent of those are outliers
# 134 values are flaged with 22232324 and 0.00 procent of those are outliers
# 14 values are flaged with 22232424 and 0.00 procent of those are outliers
# 640 values are flaged with 22242224 and 1.41 procent of those are outliers
# 7 values are flaged with 22242324 and 0.00 procent of those are outliers
# 2 values are flaged with 22242424 and 0.00 procent of those are outliers
# 42 values are flaged with 22322224 and 11.90 procent of those are outliers
# 112 values are flaged with 22322244 and 0.00 procent of those are outliers
# 15 values are flaged with 22322324 and 0.00 procent of those are outliers
# 14 values are flaged with 22322424 and 0.00 procent of those are outliers
# 20 values are flaged with 22323224 and 45.00 procent of those are outliers
# 5 values are flaged with 22323234 and 40.00 procent of those are outliers
# 7 values are flaged with 22324224 and 14.29 procent of those are outliers
# 5 values are flaged with 22324234 and 0.00 procent of those are outliers
# 19 values are flaged with 22332224 and 0.00 procent of those are outliers
# 45 values are flaged with 22332324 and 0.00 procent of those are outliers
# 20 values are flaged with 22332424 and 0.00 procent of those are outliers
# 3 values are flaged with 22342224 and 0.00 procent of those are outliers
# 12 values are flaged with 22342324 and 0.00 procent of those are outliers
# 15 values are flaged with 22342424 and 0.00 procent of those are outliers
# 3 values are flaged with 22422424 and 0.00 procent of those are outliers
# 1 values are flaged with 22432324 and 0.00 procent of those are outliers
# 4 values are flaged with 22432424 and 0.00 procent of those are outliers
# 2 values are flaged with 22442324 and 0.00 procent of those are outliers
# 4 values are flaged with 22442424 and 0.00 procent of those are outliers
# 3 values are flaged with 33333334 and 100.00 procent of those are outliers
# 1 values are flaged with 33333434 and 0.00 procent of those are outliers
# 4 values are flaged with 33334344 and 100.00 procent of those are outliers
# 6 values are flaged with 33343334 and 50.00 procent of those are outliers
# 6 values are flaged with 33343434 and 0.00 procent of those are outliers
# 1 values are flaged with 33433434 and 0.00 procent of those are outliers
# 1 values are flaged with 33443434 and 0.00 procent of those are outliers
# 10 values are flaged with 44444444 and 100.00 procent of those are outliers

# %% [markdown]
# The fourth digit have a great influence on outliers it is the "At least one of 4 nearest ASM samples is su
# spicious" flag

# %%
np.unique(FAC.Flags_F).astype('int_')
# Out:
# array([22222224, 22222234, 22222244, 22222324, 22222424, 22223224,
#        22223234, 22223244, 22224224, 22224244, 22232224, 22232234,
#        22232244, 22232324, 22232424, 22242224, 22242324, 22242424,
#        22322224, 22322244, 22322324, 22322424, 22323224, 22323234,
#        22324224, 22324234, 22332224, 22332324, 22332424, 22342224,
#        22342324, 22342424, 22422424, 22432324, 22432424, 22442324,
#        22442424, 33333334, 33333434, 33334344, 33343334, 33343434,
#        33433434, 33443434, 44444444])

# %%
((np.unique(FAC.Flags_F)%10**4)/1000).astype('int_')
# Out:
# array([2, 2, 2, 2, 2, 3, 3, 3, 4, 4, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 3,
#        3, 4, 4, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 3, 3, 4, 3, 3, 3, 3, 4])

# %%
flags = len(FAC[(((FAC.Flags_F%10**4)/1000).astype('int_')>2)])
flag_odd = len(FAC[(((FAC.Flags_F%10**4)/1000).astype('int_')>2)&(abs(FAC.FAC)>20)])

print("Flag observations is %d out off %d or %.2f procent" % (flags,N_total,flags/N_total*100))
print("Flaged odd values %d out off %d or %.2f procent" % (flag_odd,odd_val,flag_odd/odd_val*100))
# Out:
# Flag observations is 119 out off 2793344 or 0.00 procent
# Flaged odd values 41 out off 116 or 35.34 procent

# %% [markdown]
# # Flags_B

# %%
np.unique(FAC.Flags_B).astype('int32')
# Out:
# array([       2,       12,       22,       32,       42,      102,
#            1002,     2002,    10002, 11110113, 11111113, 11111123,
#        11112113, 22222224], dtype=int32)

# %%
flags = len(FAC[(FAC.Flags_B!=2)])
flag_odd = len(FAC[(FAC.Flags_B!=2)&(abs(FAC.FAC)>20)])

print("Flag observations is %d out off %d or %.2f procent" % (flags,N_total,flags/N_total*100))
print("Flaged odd values %d out off %d or %.2f procent" % (flag_odd,odd_val,flag_odd/odd_val*100))
# Out:
# Flag observations is 3241 out off 2793344 or 0.12 procent
# Flaged odd values 69 out off 116 or 59.48 procent

# %%
flags_codes = np.unique(FAC.Flags_B).astype('int32')
obs_remove = np.zeros(len(flags_codes))
odd_remove = np.zeros(len(flags_codes))

obs_remove[0] = len(FAC[(FAC.Flags_B>flags_codes[0])])
odd_remove[0] = len(FAC[(FAC.Flags_B>flags_codes[0])&(abs(FAC.FAC)>20)])

for i in range(1,len(flags_codes)):
    obs_remove[i] = len(FAC[(FAC.Flags_B>flags_codes[i])])
    odd_remove[i] = len(FAC[(FAC.Flags_B>flags_codes[i])&(abs(FAC.FAC)>20)])
    n = obs_remove[i-1]-obs_remove[i]
    n_odd = odd_remove[i-1]-odd_remove[i]
    print("%d values are flaged with %d and %.2f procent of those are outliers" % (n,flags_codes[i],n_odd/n*100))
# Out:
# 150 values are flaged with 12 and 2.67 procent of those are outliers
# 1293 values are flaged with 22 and 0.00 procent of those are outliers
# 5 values are flaged with 32 and 0.00 procent of those are outliers
# 32 values are flaged with 42 and 0.00 procent of those are outliers
# 2 values are flaged with 102 and 0.00 procent of those are outliers
# 1156 values are flaged with 1002 and 2.77 procent of those are outliers
# 555 values are flaged with 2002 and 0.54 procent of those are outliers
# 4 values are flaged with 10002 and 0.00 procent of those are outliers
# 4 values are flaged with 11110113 and 100.00 procent of those are outliers
# 27 values are flaged with 11111113 and 48.15 procent of those are outliers
# 1 values are flaged with 11111123 and 100.00 procent of those are outliers
# 2 values are flaged with 11112113 and 100.00 procent of those are outliers
# 10 values are flaged with 22222224 and 100.00 procent of those are outliers

# %% [markdown]
# The first five digit does not cours a lot of difference. The rest is "Discrepancy between ASM and VFM measurements"

# %%
flags = len(FAC[(FAC.Flags_B>10002)])
flag_odd = len(FAC[(FAC.Flags_B>10002)&(abs(FAC.FAC)>20)])

print("Flag observations is %d out off %d or %.2f procent" % (flags,N_total,flags/N_total*100))
print("Flaged odd values %d out off %d or %.2f procent" % (flag_odd,odd_val,flag_odd/odd_val*100))
# Out:
# Flag observations is 44 out off 2793344 or 0.00 procent
# Flaged odd values 30 out off 116 or 25.86 procent

# %% [markdown]
# Conclusion is that flags_B over 10002 should not be included

# %% [markdown]
# ## Flags_q

# %%
np.unique(FAC.Flags_q)
# Out:
# array([  0.00000000e+00,   1.00000000e+00,   2.00000000e+00,
#          3.00000000e+00,   4.00000000e+00,   1.00000000e+01,
#          1.10000000e+01,   2.00000000e+01,   2.20000000e+01,
#          1.00000000e+02,   1.01000000e+02,   1.02000000e+02,
#          1.03000000e+02,   1.10000000e+02,   1.11000000e+02,
#          1.21000000e+02,   2.00000000e+02,   2.01000000e+02,
#          2.02000000e+02,   2.20000000e+02,   3.00000000e+02,
#          3.01000000e+02,   4.00000000e+02,   4.04000000e+02,
#          4.40000000e+02,   1.00000000e+04,   1.00010000e+04,
#          1.00020000e+04,   1.00030000e+04,   1.00040000e+04,
#          1.00100000e+04,   1.00110000e+04,   1.00120000e+04,
#          1.00210000e+04,   1.01000000e+04,   1.01010000e+04,
#          1.01020000e+04,   1.01030000e+04,   1.01100000e+04,
#          1.01110000e+04,   1.01120000e+04,   1.01200000e+04,
#          1.02000000e+04,   1.02010000e+04,   1.02100000e+04,
#          1.02300000e+04,   1.03000000e+04,   1.03040000e+04,
#          1.03400000e+04,   1.04000000e+04,   2.00000000e+04,
#          2.00010000e+04,   2.00020000e+04,   2.00030000e+04,
#          2.00040000e+04,   2.00100000e+04,   2.00110000e+04,
#          2.00120000e+04,   2.00130000e+04,   2.00200000e+04,
#          2.00210000e+04,   2.00220000e+04,   2.00310000e+04,
#          2.01000000e+04,   2.01010000e+04,   2.01020000e+04,
#          2.01030000e+04,   2.01110000e+04,   2.01130000e+04,
#          2.01200000e+04,   2.01210000e+04,   2.01300000e+04,
#          2.01410000e+04,   2.02000000e+04,   2.02020000e+04,
#          2.02040000e+04,   2.02200000e+04,   2.02400000e+04,
#          3.00000000e+04,   3.00010000e+04,   3.00020000e+04,
#          3.00030000e+04,   3.00100000e+04,   3.00110000e+04,
#          3.00120000e+04,   3.00130000e+04,   3.00140000e+04,
#          3.00200000e+04,   3.00210000e+04,   3.00300000e+04,
#          3.00410000e+04,   3.01000000e+04,   3.01040000e+04,
#          3.01100000e+04,   3.01110000e+04,   3.01400000e+04,
#          4.00000000e+04,   4.00010000e+04,   4.00020000e+04,
#          4.00030000e+04,   4.00040000e+04,   4.00100000e+04,
#          4.00110000e+04,   4.00120000e+04,   4.00130000e+04,
#          4.00200000e+04,   4.00220000e+04,   4.00300000e+04,
#          4.00310000e+04,   4.00400000e+04,   4.01000000e+04,
#          4.01200000e+04,   4.01300000e+04,   1.00000000e+05,
#          1.00001000e+05,   1.00010000e+05,   1.00011000e+05,
#          1.00101000e+05,   1.00102000e+05,   1.00110000e+05,
#          1.00111000e+05,   1.00211000e+05,   1.00301000e+05,
#          1.00303000e+05,   1.00310000e+05,   1.00313000e+05,
#          1.00314000e+05,   1.00330000e+05,   1.00331000e+05,
#          1.10001000e+05,   1.10010000e+05,   1.10011000e+05,
#          1.10012000e+05,   1.10013000e+05,   1.10021000e+05,
#          1.10101000e+05,   1.10102000e+05,   1.10111000e+05,
#          1.10112000e+05,   1.10201000e+05,   1.10202000e+05,
#          1.10203000e+05,   1.10210000e+05,   1.10211000e+05,
#          1.10213000e+05,   1.10230000e+05,   1.10231000e+05,
#          1.10314000e+05,   1.10341000e+05,   1.10400000e+05,
#          1.10401000e+05,   1.10404000e+05,   1.10413000e+05,
#          1.10430000e+05,   1.20001000e+05,   1.20010000e+05,
#          1.20011000e+05,   1.20012000e+05,   1.20020000e+05,
#          1.20021000e+05,   1.20022000e+05,   1.20100000e+05,
#          1.20101000e+05,   1.20102000e+05,   1.20103000e+05,
#          1.20110000e+05,   1.20112000e+05,   1.20113000e+05,
#          1.20130000e+05,   1.20131000e+05,   1.20211000e+05,
#          1.20214000e+05,   1.20241000e+05,   1.20300000e+05,
#          1.20301000e+05,   1.20304000e+05,   1.20310000e+05,
#          1.20330000e+05,   1.20400000e+05,   1.30000000e+05,
#          1.30001000e+05,   1.30003000e+05,   1.30004000e+05,
#          1.30010000e+05,   1.30011000e+05,   1.30012000e+05,
#          1.30013000e+05,   1.30014000e+05,   1.30021000e+05,
#          1.30023000e+05,   1.30030000e+05,   1.30031000e+05,
#          1.30101000e+05,   1.30102000e+05,   1.30103000e+05,
#          1.30114000e+05,   1.30120000e+05,   1.30141000e+05,
#          1.30200000e+05,   1.30201000e+05,   1.30204000e+05,
#          1.30230000e+05,   1.40014000e+05,   1.40041000e+05,
#          1.40100000e+05,   1.40101000e+05,   1.40102000e+05,
#          1.40103000e+05,   1.40104000e+05,   1.40110000e+05,
#          1.40114000e+05,   1.40130000e+05,   2.00000000e+05,
#          2.00004000e+05,   2.00020000e+05,   2.00103000e+05,
#          2.00202000e+05,   2.00211000e+05,   2.00212000e+05,
#          2.00220000e+05,   2.00222000e+05,   2.00223000e+05,
#          2.10001000e+05,   2.10010000e+05,   2.10020000e+05,
#          2.10021000e+05,   2.10102000e+05,   2.10111000e+05,
#          2.10112000e+05,   2.10120000e+05,   2.10122000e+05,
#          2.10201000e+05,   2.10202000e+05,   2.10213000e+05,
#          2.10223000e+05,   2.10224000e+05,   2.10301000e+05,
#          2.10302000e+05,   2.10303000e+05,   2.10311000e+05,
#          2.10313000e+05,   2.10314000e+05,   2.10321000e+05,
#          2.10322000e+05,   2.20002000e+05,   2.20004000e+05,
#          2.20011000e+05,   2.20012000e+05,   2.20020000e+05,
#          2.20021000e+05,   2.20022000e+05,   2.20111000e+05,
#          2.20112000e+05,   2.20201000e+05,   2.20202000e+05,
#          2.20211000e+05,   2.20221000e+05,   2.20224000e+05,
#          2.20323000e+05,   2.20400000e+05,   2.20402000e+05,
#          2.20404000e+05,   2.20420000e+05,   2.30031000e+05,
#          2.30101000e+05,   2.30102000e+05,   2.30111000e+05,
#          2.30112000e+05,   2.30113000e+05,   2.30121000e+05,
#          2.30202000e+05,   2.30203000e+05,   2.30302000e+05,
#          2.30320000e+05,   2.40042000e+05,   2.40200000e+05,
#          2.40202000e+05,   2.40203000e+05,   2.40204000e+05,
#          2.40220000e+05,   3.00103000e+05,   3.00111000e+05,
#          3.00112000e+05,   3.00113000e+05,   3.00130000e+05,
#          3.10003000e+05,   3.10013000e+05,   3.10031000e+05,
#          3.10202000e+05,   3.10212000e+05,   3.10221000e+05,
#          3.20102000e+05,   3.20112000e+05,   3.20121000e+05,
#          3.20122000e+05,   3.20123000e+05,   3.20303000e+05,
#          3.20311000e+05,   3.20312000e+05,   3.30134000e+05,
#          3.30211000e+05,   3.30212000e+05,   3.30213000e+05,
#          3.30410000e+05,   3.40300000e+05,   3.40303000e+05,
#          3.40304000e+05,   4.00004000e+05,   4.00040000e+05,
#          4.10103000e+05,   4.10131000e+05,   4.20202000e+05,
#          4.20222000e+05,   4.20223000e+05,   4.30033000e+05,
#          4.30301000e+05,   4.30313000e+05,   4.30314000e+05,
#          4.40400000e+05,   4.40404000e+05,   1.11211110e+07,
#          1.11211120e+07,   1.11411140e+07,   1.12111210e+07,
#          1.12113230e+07,   1.12113320e+07,   1.12212120e+07,
#          1.12214140e+07,   1.12214310e+07,   1.13112230e+07,
#          1.13213220e+07,   2.22222220e+07,   2.22224240e+07,
#          2.22422240e+07])

# %%
flags = len(FAC[(FAC.Flags_q>0)])
flag_odd = len(FAC[(FAC.Flags_q>0)&(abs(FAC.FAC)>20)])

print("Flag observations is %d out off %d or %.2f procent" % (flags,N_total,flags/N_total*100))
print("Flaged odd values %d out off %d or %.2f procent" % (flag_odd,odd_val,flag_odd/odd_val*100))
# Out:
# Flag observations is 1204252 out off 2793344 or 43.11 procent
# Flaged odd values 107 out off 116 or 92.24 procent

# %%
flags_codes = np.unique(FAC.Flags_q).astype('int32')
obs_remove = np.zeros(len(flags_codes))
odd_remove = np.zeros(len(flags_codes))
obs_remove[0] = len(FAC[(FAC.Flags_q>flags_codes[0])])
odd_remove[0] = len(FAC[(FAC.Flags_q>flags_codes[0])&(abs(FAC.FAC)>20)])

for i in range(1,len(flags_codes)):
    obs_remove[i] = len(FAC[(FAC.Flags_q>flags_codes[i])])
    odd_remove[i] = len(FAC[(FAC.Flags_q>flags_codes[i])&(abs(FAC.FAC)>20)])
    n = obs_remove[i-1]-obs_remove[i]
    n_odd = odd_remove[i-1]-odd_remove[i]
    print("%d values are flaged with %d and %.2f procent of those are outliers" % (n,flags_codes[i],n_odd/n*100))
# Out:
# 2577 values are flaged with 1 and 0.00 procent of those are outliers
# 1330 values are flaged with 2 and 0.00 procent of those are outliers
# 41 values are flaged with 3 and 0.00 procent of those are outliers
# 11 values are flaged with 4 and 0.00 procent of those are outliers
# 469 values are flaged with 10 and 0.00 procent of those are outliers
# 120 values are flaged with 11 and 0.00 procent of those are outliers
# 23 values are flaged with 20 and 0.00 procent of those are outliers
# 4 values are flaged with 22 and 0.00 procent of those are outliers
# 605 values are flaged with 100 and 0.00 procent of those are outliers
# 1230 values are flaged with 101 and 0.00 procent of those are outliers
# 35 values are flaged with 102 and 0.00 procent of those are outliers
# 7 values are flaged with 103 and 0.00 procent of those are outliers
# 6 values are flaged with 110 and 0.00 procent of those are outliers
# 8 values are flaged with 111 and 0.00 procent of those are outliers
# 1 values are flaged with 121 and 0.00 procent of those are outliers
# 3670 values are flaged with 200 and 0.00 procent of those are outliers
# 394 values are flaged with 201 and 0.00 procent of those are outliers
# 348 values are flaged with 202 and 0.00 procent of those are outliers
# 4 values are flaged with 220 and 0.00 procent of those are outliers
# 20 values are flaged with 300 and 0.00 procent of those are outliers
# 521 values are flaged with 301 and 0.00 procent of those are outliers
# 234309 values are flaged with 400 and 0.00 procent of those are outliers
# 316008 values are flaged with 404 and 0.00 procent of those are outliers
# 22870 values are flaged with 440 and 0.00 procent of those are outliers
# 13021 values are flaged with 10000 and 0.00 procent of those are outliers
# 8924 values are flaged with 10001 and 0.00 procent of those are outliers
# 41 values are flaged with 10002 and 0.00 procent of those are outliers
# 31 values are flaged with 10003 and 0.00 procent of those are outliers
# 2 values are flaged with 10004 and 0.00 procent of those are outliers
# 5447 values are flaged with 10010 and 0.00 procent of those are outliers
# 93 values are flaged with 10011 and 0.00 procent of those are outliers
# 5 values are flaged with 10012 and 0.00 procent of those are outliers
# 24 values are flaged with 10021 and 0.00 procent of those are outliers
# 1487 values are flaged with 10100 and 0.00 procent of those are outliers
# 161 values are flaged with 10101 and 0.00 procent of those are outliers
# 408 values are flaged with 10102 and 0.00 procent of those are outliers
# 1 values are flaged with 10103 and 0.00 procent of those are outliers
# 2 values are flaged with 10110 and 0.00 procent of those are outliers
# 7 values are flaged with 10111 and 0.00 procent of those are outliers
# 2 values are flaged with 10112 and 0.00 procent of those are outliers
# 83 values are flaged with 10120 and 0.00 procent of those are outliers
# 517 values are flaged with 10200 and 0.00 procent of those are outliers
# 451 values are flaged with 10201 and 0.00 procent of those are outliers
# 8 values are flaged with 10210 and 0.00 procent of those are outliers
# 5 values are flaged with 10230 and 0.00 procent of those are outliers
# 9741 values are flaged with 10300 and 0.00 procent of those are outliers
# 4177 values are flaged with 10304 and 0.00 procent of those are outliers
# 894 values are flaged with 10340 and 0.00 procent of those are outliers
# 2 values are flaged with 10400 and 0.00 procent of those are outliers
# 24611 values are flaged with 20000 and 0.01 procent of those are outliers
# 737 values are flaged with 20001 and 0.00 procent of those are outliers
# 32083 values are flaged with 20002 and 0.00 procent of those are outliers
# 31 values are flaged with 20003 and 0.00 procent of those are outliers
# 1 values are flaged with 20004 and 0.00 procent of those are outliers
# 68 values are flaged with 20010 and 0.00 procent of those are outliers
# 73 values are flaged with 20011 and 0.00 procent of those are outliers
# 48 values are flaged with 20012 and 0.00 procent of those are outliers
# 5 values are flaged with 20013 and 0.00 procent of those are outliers
# 8414 values are flaged with 20020 and 0.00 procent of those are outliers
# 10 values are flaged with 20021 and 0.00 procent of those are outliers
# 3 values are flaged with 20022 and 0.00 procent of those are outliers
# 10 values are flaged with 20031 and 0.00 procent of those are outliers
# 354 values are flaged with 20100 and 0.00 procent of those are outliers
# 1077 values are flaged with 20101 and 0.00 procent of those are outliers
# 4 values are flaged with 20102 and 0.00 procent of those are outliers
# 20 values are flaged with 20103 and 0.00 procent of those are outliers
# 1 values are flaged with 20111 and 0.00 procent of those are outliers
# 1 values are flaged with 20113 and 0.00 procent of those are outliers
# 7 values are flaged with 20120 and 0.00 procent of those are outliers
# 18 values are flaged with 20121 and 0.00 procent of those are outliers
# 13 values are flaged with 20130 and 0.00 procent of those are outliers
# 1 values are flaged with 20141 and 0.00 procent of those are outliers
# 30516 values are flaged with 20200 and 0.00 procent of those are outliers
# 5 values are flaged with 20202 and 0.00 procent of those are outliers
# 60522 values are flaged with 20204 and 0.00 procent of those are outliers
# 15 values are flaged with 20220 and 0.00 procent of those are outliers
# 3170 values are flaged with 20240 and 0.00 procent of those are outliers
# 5194 values are flaged with 30000 and 0.00 procent of those are outliers
# 843 values are flaged with 30001 and 0.00 procent of those are outliers
# 87 values are flaged with 30002 and 0.00 procent of those are outliers
# 3423 values are flaged with 30003 and 0.00 procent of those are outliers
# 10 values are flaged with 30010 and 0.00 procent of those are outliers
# 12 values are flaged with 30011 and 0.00 procent of those are outliers
# 28 values are flaged with 30012 and 0.00 procent of those are outliers
# 73 values are flaged with 30013 and 0.00 procent of those are outliers
# 4 values are flaged with 30014 and 0.00 procent of those are outliers
# 6 values are flaged with 30020 and 0.00 procent of those are outliers
# 7 values are flaged with 30021 and 0.00 procent of those are outliers
# 1098 values are flaged with 30030 and 0.00 procent of those are outliers
# 17 values are flaged with 30041 and 0.00 procent of those are outliers
# 13473 values are flaged with 30100 and 0.00 procent of those are outliers
# 3469 values are flaged with 30104 and 0.00 procent of those are outliers
# 1 values are flaged with 30110 and 0.00 procent of those are outliers
# 6 values are flaged with 30111 and 0.00 procent of those are outliers
# 1799 values are flaged with 30140 and 0.00 procent of those are outliers
# 146579 values are flaged with 40000 and 0.00 procent of those are outliers
# 11 values are flaged with 40001 and 0.00 procent of those are outliers
# 304 values are flaged with 40002 and 0.00 procent of those are outliers
# 15 values are flaged with 40003 and 0.00 procent of those are outliers
# 187196 values are flaged with 40004 and 0.01 procent of those are outliers
# 2 values are flaged with 40010 and 0.00 procent of those are outliers
# 4 values are flaged with 40011 and 0.00 procent of those are outliers
# 5 values are flaged with 40012 and 0.00 procent of those are outliers
# 7 values are flaged with 40013 and 0.00 procent of those are outliers
# 2 values are flaged with 40020 and 0.00 procent of those are outliers
# 1 values are flaged with 40022 and 0.00 procent of those are outliers
# 4 values are flaged with 40030 and 0.00 procent of those are outliers
# 1 values are flaged with 40031 and 0.00 procent of those are outliers
# 26430 values are flaged with 40040 and 0.00 procent of those are outliers
# 2 values are flaged with 40100 and 0.00 procent of those are outliers
# 1 values are flaged with 40120 and 0.00 procent of those are outliers
# 1 values are flaged with 40130 and 0.00 procent of those are outliers
# 1 values are flaged with 100000 and 0.00 procent of those are outliers
# 15 values are flaged with 100001 and 0.00 procent of those are outliers
# 36 values are flaged with 100010 and 0.00 procent of those are outliers
# 8 values are flaged with 100011 and 0.00 procent of those are outliers
# 1 values are flaged with 100101 and 0.00 procent of those are outliers
# 1 values are flaged with 100102 and 0.00 procent of those are outliers
# 3 values are flaged with 100110 and 0.00 procent of those are outliers
# 3 values are flaged with 100111 and 0.00 procent of those are outliers
# 2 values are flaged with 100211 and 0.00 procent of those are outliers
# 1556 values are flaged with 100301 and 0.00 procent of those are outliers
# 501 values are flaged with 100303 and 0.00 procent of those are outliers
# 883 values are flaged with 100310 and 0.00 procent of those are outliers
# 434 values are flaged with 100313 and 0.23 procent of those are outliers
# 1 values are flaged with 100314 and 0.00 procent of those are outliers
# 66 values are flaged with 100330 and 0.00 procent of those are outliers
# 118 values are flaged with 100331 and 0.00 procent of those are outliers
# 24 values are flaged with 110001 and 0.00 procent of those are outliers
# 63 values are flaged with 110010 and 7.94 procent of those are outliers
# 150 values are flaged with 110011 and 0.67 procent of those are outliers
# 8 values are flaged with 110012 and 0.00 procent of those are outliers
# 6 values are flaged with 110013 and 0.00 procent of those are outliers
# 3 values are flaged with 110021 and 0.00 procent of those are outliers
# 9 values are flaged with 110101 and 0.00 procent of those are outliers
# 3 values are flaged with 110102 and 0.00 procent of those are outliers
# 4 values are flaged with 110111 and 0.00 procent of those are outliers
# 9 values are flaged with 110112 and 0.00 procent of those are outliers
# 73 values are flaged with 110201 and 0.00 procent of those are outliers
# 3 values are flaged with 110202 and 0.00 procent of those are outliers
# 58 values are flaged with 110203 and 0.00 procent of those are outliers
# 61 values are flaged with 110210 and 0.00 procent of those are outliers
# 4 values are flaged with 110211 and 0.00 procent of those are outliers
# 70 values are flaged with 110213 and 0.00 procent of those are outliers
# 20 values are flaged with 110230 and 0.00 procent of those are outliers
# 70 values are flaged with 110231 and 0.00 procent of those are outliers
# 116 values are flaged with 110314 and 0.00 procent of those are outliers
# 10 values are flaged with 110341 and 0.00 procent of those are outliers
# 122 values are flaged with 110400 and 0.00 procent of those are outliers
# 277 values are flaged with 110401 and 0.00 procent of those are outliers
# 136 values are flaged with 110404 and 0.00 procent of those are outliers
# 3 values are flaged with 110413 and 0.00 procent of those are outliers
# 63 values are flaged with 110430 and 0.00 procent of those are outliers
# 2 values are flaged with 120001 and 0.00 procent of those are outliers
# 15 values are flaged with 120010 and 0.00 procent of those are outliers
# 25 values are flaged with 120011 and 0.00 procent of those are outliers
# 21 values are flaged with 120012 and 0.00 procent of those are outliers
# 3 values are flaged with 120020 and 0.00 procent of those are outliers
# 9 values are flaged with 120021 and 0.00 procent of those are outliers
# 1 values are flaged with 120022 and 0.00 procent of those are outliers
# 2 values are flaged with 120100 and 0.00 procent of those are outliers
# 73 values are flaged with 120101 and 0.00 procent of those are outliers
# 63 values are flaged with 120102 and 0.00 procent of those are outliers
# 81 values are flaged with 120103 and 0.00 procent of those are outliers
# 106 values are flaged with 120110 and 0.00 procent of those are outliers
# 2 values are flaged with 120112 and 0.00 procent of those are outliers
# 30 values are flaged with 120113 and 0.00 procent of those are outliers
# 27 values are flaged with 120130 and 0.00 procent of those are outliers
# 41 values are flaged with 120131 and 0.00 procent of those are outliers
# 2 values are flaged with 120211 and 0.00 procent of those are outliers
# 13 values are flaged with 120214 and 0.00 procent of those are outliers
# 1 values are flaged with 120241 and 0.00 procent of those are outliers
# 4 values are flaged with 120300 and 0.00 procent of those are outliers
# 23 values are flaged with 120301 and 0.00 procent of those are outliers
# 11 values are flaged with 120304 and 0.00 procent of those are outliers
# 1 values are flaged with 120310 and 0.00 procent of those are outliers
# 42 values are flaged with 120330 and 0.00 procent of those are outliers
# 2 values are flaged with 120400 and 0.00 procent of those are outliers
# 14 values are flaged with 130000 and 0.00 procent of those are outliers
# 362 values are flaged with 130001 and 0.00 procent of those are outliers
# 293 values are flaged with 130003 and 0.00 procent of those are outliers
# 96 values are flaged with 130004 and 0.00 procent of those are outliers
# 434 values are flaged with 130010 and 0.00 procent of those are outliers
# 40 values are flaged with 130011 and 0.00 procent of those are outliers
# 12 values are flaged with 130012 and 0.00 procent of those are outliers
# 650 values are flaged with 130013 and 0.00 procent of those are outliers
# 5 values are flaged with 130014 and 0.00 procent of those are outliers
# 3 values are flaged with 130021 and 0.00 procent of those are outliers
# 2 values are flaged with 130023 and 0.00 procent of those are outliers
# 88 values are flaged with 130030 and 0.00 procent of those are outliers
# 198 values are flaged with 130031 and 0.00 procent of those are outliers
# 5 values are flaged with 130101 and 0.00 procent of those are outliers
# 8 values are flaged with 130102 and 0.00 procent of those are outliers
# 8 values are flaged with 130103 and 0.00 procent of those are outliers
# 9 values are flaged with 130114 and 0.00 procent of those are outliers
# 2 values are flaged with 130120 and 0.00 procent of those are outliers
# 3 values are flaged with 130141 and 0.00 procent of those are outliers
# 5 values are flaged with 130200 and 0.00 procent of those are outliers
# 19 values are flaged with 130201 and 0.00 procent of those are outliers
# 15 values are flaged with 130204 and 0.00 procent of those are outliers
# 18 values are flaged with 130230 and 0.00 procent of those are outliers
# 28 values are flaged with 140014 and 0.00 procent of those are outliers
# 12 values are flaged with 140041 and 0.00 procent of those are outliers
# 45 values are flaged with 140100 and 0.00 procent of those are outliers
# 114 values are flaged with 140101 and 0.00 procent of those are outliers
# 45 values are flaged with 140102 and 0.00 procent of those are outliers
# 12 values are flaged with 140103 and 0.00 procent of those are outliers
# 287 values are flaged with 140104 and 0.00 procent of those are outliers
# 1 values are flaged with 140110 and 0.00 procent of those are outliers
# 2 values are flaged with 140114 and 0.00 procent of those are outliers
# 78 values are flaged with 140130 and 0.00 procent of those are outliers
# 2 values are flaged with 200000 and 0.00 procent of those are outliers
# 1 values are flaged with 200004 and 0.00 procent of those are outliers
# 29 values are flaged with 200020 and 6.90 procent of those are outliers
# 2 values are flaged with 200103 and 0.00 procent of those are outliers
# 240 values are flaged with 200202 and 0.00 procent of those are outliers
# 37 values are flaged with 200211 and 0.00 procent of those are outliers
# 5 values are flaged with 200212 and 0.00 procent of those are outliers
# 69 values are flaged with 200220 and 0.00 procent of those are outliers
# 74 values are flaged with 200222 and 2.70 procent of those are outliers
# 4 values are flaged with 200223 and 0.00 procent of those are outliers
# 1 values are flaged with 210001 and 0.00 procent of those are outliers
# 2 values are flaged with 210010 and 0.00 procent of those are outliers
# 14 values are flaged with 210020 and 0.00 procent of those are outliers
# 3 values are flaged with 210021 and 0.00 procent of those are outliers
# 19 values are flaged with 210102 and 0.00 procent of those are outliers
# 43 values are flaged with 210111 and 0.00 procent of those are outliers
# 3 values are flaged with 210112 and 0.00 procent of those are outliers
# 3 values are flaged with 210120 and 0.00 procent of those are outliers
# 17 values are flaged with 210122 and 0.00 procent of those are outliers
# 1 values are flaged with 210201 and 0.00 procent of those are outliers
# 1 values are flaged with 210202 and 0.00 procent of those are outliers
# 29 values are flaged with 210213 and 0.00 procent of those are outliers
# 7 values are flaged with 210223 and 0.00 procent of those are outliers
# 1 values are flaged with 210224 and 0.00 procent of those are outliers
# 37 values are flaged with 210301 and 0.00 procent of those are outliers
# 4 values are flaged with 210302 and 0.00 procent of those are outliers
# 1 values are flaged with 210303 and 0.00 procent of those are outliers
# 197 values are flaged with 210311 and 0.00 procent of those are outliers
# 66 values are flaged with 210313 and 4.55 procent of those are outliers
# 2 values are flaged with 210314 and 0.00 procent of those are outliers
# 75 values are flaged with 210321 and 0.00 procent of those are outliers
# 10 values are flaged with 210322 and 0.00 procent of those are outliers
# 34 values are flaged with 220002 and 0.00 procent of those are outliers
# 5 values are flaged with 220004 and 0.00 procent of those are outliers
# 14 values are flaged with 220011 and 0.00 procent of those are outliers
# 3 values are flaged with 220012 and 0.00 procent of those are outliers
# 29 values are flaged with 220020 and 0.00 procent of those are outliers
# 3 values are flaged with 220021 and 0.00 procent of those are outliers
# 271 values are flaged with 220022 and 0.00 procent of those are outliers
# 13 values are flaged with 220111 and 0.00 procent of those are outliers
# 11 values are flaged with 220112 and 0.00 procent of those are outliers
# 5 values are flaged with 220201 and 0.00 procent of those are outliers
# 33 values are flaged with 220202 and 12.12 procent of those are outliers
# 7 values are flaged with 220211 and 0.00 procent of those are outliers
# 20 values are flaged with 220221 and 0.00 procent of those are outliers
# 75 values are flaged with 220224 and 0.00 procent of those are outliers
# 3 values are flaged with 220323 and 0.00 procent of those are outliers
# 1 values are flaged with 220400 and 0.00 procent of those are outliers
# 262 values are flaged with 220402 and 0.00 procent of those are outliers
# 23 values are flaged with 220404 and 4.35 procent of those are outliers
# 80 values are flaged with 220420 and 0.00 procent of those are outliers
# 8 values are flaged with 230031 and 0.00 procent of those are outliers
# 30 values are flaged with 230101 and 0.00 procent of those are outliers
# 2 values are flaged with 230102 and 0.00 procent of those are outliers
# 102 values are flaged with 230111 and 0.00 procent of those are outliers
# 3 values are flaged with 230112 and 0.00 procent of those are outliers
# 391 values are flaged with 230113 and 0.00 procent of those are outliers
# 87 values are flaged with 230121 and 0.00 procent of those are outliers
# 18 values are flaged with 230202 and 0.00 procent of those are outliers
# 5 values are flaged with 230203 and 0.00 procent of those are outliers
# 3 values are flaged with 230302 and 0.00 procent of those are outliers
# 13 values are flaged with 230320 and 0.00 procent of those are outliers
# 3 values are flaged with 240042 and 0.00 procent of those are outliers
# 50 values are flaged with 240200 and 0.00 procent of those are outliers
# 1283 values are flaged with 240202 and 0.00 procent of those are outliers
# 1 values are flaged with 240203 and 0.00 procent of those are outliers
# 887 values are flaged with 240204 and 0.00 procent of those are outliers
# 84 values are flaged with 240220 and 0.00 procent of those are outliers
# 9 values are flaged with 300103 and 0.00 procent of those are outliers
# 1 values are flaged with 300111 and 0.00 procent of those are outliers
# 4 values are flaged with 300112 and 0.00 procent of those are outliers
# 1 values are flaged with 300113 and 0.00 procent of those are outliers
# 5 values are flaged with 300130 and 0.00 procent of those are outliers
# 1 values are flaged with 310003 and 0.00 procent of those are outliers
# 1 values are flaged with 310013 and 0.00 procent of those are outliers
# 21 values are flaged with 310031 and 0.00 procent of those are outliers
# 2 values are flaged with 310202 and 0.00 procent of those are outliers
# 14 values are flaged with 310212 and 7.14 procent of those are outliers
# 17 values are flaged with 310221 and 0.00 procent of those are outliers
# 2 values are flaged with 320102 and 0.00 procent of those are outliers
# 4 values are flaged with 320112 and 0.00 procent of those are outliers
# 2 values are flaged with 320121 and 0.00 procent of those are outliers
# 39 values are flaged with 320122 and 0.00 procent of those are outliers
# 2 values are flaged with 320123 and 0.00 procent of those are outliers
# 4 values are flaged with 320303 and 0.00 procent of those are outliers
# 16 values are flaged with 320311 and 6.25 procent of those are outliers
# 4 values are flaged with 320312 and 0.00 procent of those are outliers
# 3 values are flaged with 330134 and 0.00 procent of those are outliers
# 8 values are flaged with 330211 and 0.00 procent of those are outliers
# 60 values are flaged with 330212 and 0.00 procent of those are outliers
# 285 values are flaged with 330213 and 0.00 procent of those are outliers
# 4 values are flaged with 330410 and 0.00 procent of those are outliers
# 2 values are flaged with 340300 and 0.00 procent of those are outliers
# 63 values are flaged with 340303 and 0.00 procent of those are outliers
# 190 values are flaged with 340304 and 0.00 procent of those are outliers
# 5 values are flaged with 400004 and 0.00 procent of those are outliers
# 2 values are flaged with 400040 and 0.00 procent of those are outliers
# 13 values are flaged with 410103 and 0.00 procent of those are outliers
# 6 values are flaged with 410131 and 0.00 procent of those are outliers
# 10 values are flaged with 420202 and 10.00 procent of those are outliers
# 133 values are flaged with 420222 and 0.00 procent of those are outliers
# 1 values are flaged with 420223 and 0.00 procent of those are outliers
# 2 values are flaged with 430033 and 0.00 procent of those are outliers
# 3 values are flaged with 430301 and 0.00 procent of those are outliers
# 395 values are flaged with 430313 and 0.00 procent of those are outliers
# 1 values are flaged with 430314 and 0.00 procent of those are outliers
# 14 values are flaged with 440400 and 0.00 procent of those are outliers
# 7398 values are flaged with 440404 and 0.00 procent of those are outliers
# 5 values are flaged with 11121111 and 100.00 procent of those are outliers
# 2 values are flaged with 11121112 and 100.00 procent of those are outliers
# 10 values are flaged with 11141114 and 100.00 procent of those are outliers
# 8 values are flaged with 11211121 and 100.00 procent of those are outliers
# 5 values are flaged with 11211323 and 100.00 procent of those are outliers
# 1 values are flaged with 11211332 and 100.00 procent of those are outliers
# 5 values are flaged with 11221212 and 100.00 procent of those are outliers
# 5 values are flaged with 11221414 and 100.00 procent of those are outliers
# 1 values are flaged with 11221431 and 100.00 procent of those are outliers
# 1 values are flaged with 11311223 and 100.00 procent of those are outliers
# 3 values are flaged with 11321322 and 100.00 procent of those are outliers
# 2 values are flaged with 22222222 and 100.00 procent of those are outliers
# 1 values are flaged with 22222424 and 100.00 procent of those are outliers
# 10 values are flaged with 22242224 and 100.00 procent of those are outliers

# %% [markdown]
# The first six digit does not cours a lot of difference. The rest is "On-ground aberrational correction of any attitude sample among 4 nearest STR samples."

# %%
flags = len(FAC[(FAC.Flags_q>440404)])
flag_odd = len(FAC[(FAC.Flags_q>440404)&(abs(FAC.FAC)>20)])

print("Flag observations is %d out off %d or %.2f procent" % (flags,N_total,flags/N_total*100))
print("Flaged odd values %d out off %d or %.2f procent" % (flag_odd,odd_val,flag_odd/odd_val*100))
# Out:
# Flag observations is 59 out off 2793344 or 0.00 procent
# Flaged odd values 59 out off 116 or 50.86 procent

# %% [markdown]
# ## Combined

# %%
flags = len(FAC[(FAC.Flags_B>10002)|(FAC.Flags_q>440404)])
flag_odd = len(FAC[((FAC.Flags_B>10002)|(FAC.Flags_q>440404))&(abs(FAC.FAC)>20)])

print("Flag observations is %d out off %d or %.2f procent" % (flags,N_total,flags/N_total*100))
print("Flaged odd values %d out off %d or %.2f procent" % (flag_odd,odd_val,flag_odd/odd_val*100))
# Out:
# Flag observations is 85 out off 2793344 or 0.00 procent
# Flaged odd values 71 out off 116 or 61.21 procent

# %%
flags = len(FAC[(FAC.Flags_B>10002)|(FAC.Flags_q>440404)|(((FAC.Flags_F%10**4)/1000).astype('int_')>2)])
flag_odd = len(FAC[((FAC.Flags_B>10002)|(FAC.Flags_q>440404)|(((FAC.Flags_F%10**4)/1000).astype('int_')>2))&(abs(FAC.FAC)>20)])

print("Flag observations is %d out off %d or %.2f procent" % (flags,N_total,flags/N_total*100))
print("Flaged odd values %d out off %d or %.2f procent" % (flag_odd,odd_val,flag_odd/odd_val*100))
# Out:
# Flag observations is 168 out off 2793344 or 0.01 procent
# Flaged odd values 85 out off 116 or 73.28 procent

# %%
flags = len(FAC[(FAC.Flags_B>2)|(FAC.Flags_q>440404)|(FAC.Flags_F>22222234)])
flag_odd = len(FAC[((FAC.Flags_B>2)|(FAC.Flags_q>440404)|(FAC.Flags_F>22222234))&(abs(FAC.FAC)>20)])

print("Flag observations is %d out off %d or %.2f procent" % (flags,N_total,flags/N_total*100))
print("Flaged odd values %d out off %d or %.2f procent" % (flag_odd,odd_val,flag_odd/odd_val*100))
# Out:
# Flag observations is 49449 out off 2793344 or 1.77 procent
# Flaged odd values 94 out off 116 or 81.03 procent

# %%
plt.figure()

p1 = FAC.FAC.plot(legend=True)
p1.set_ylabel('$\mu$A/$m^2$')
plt.title('initial data')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,'initial data')

# %%
plt.figure()

p1 = FAC[(FAC.Flags_B<=10002)&(FAC.Flags_q<=440404)&(((FAC.Flags_F%10**4)/1000).astype('int_')<=2)].FAC.plot(legend=True)
p1.set_ylabel('$\mu$A/$m^2$')
plt.title('The Filtered data')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,'The Filtered data')

# %%
len(FAC[(FAC.Flags_B<=10002)&(FAC.Flags_q<=440404)|(((FAC.Flags_F%10**4)/1000).astype('int_')<=2)])
# Out:
# 2793326

# %%
len(FAC)-len(FAC[(FAC.Flags_B<=10002)&(FAC.Flags_q<=440404)&(((FAC.Flags_F%10**4)/1000).astype('int_')<=2)])
# Out:
# 168
