# %% [markdown]
# # Correlation

# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from scipy import signal
import seaborn as sns
sns.set()

# %%
Half_orbit = pd.read_pickle('/home/simon/Desktop/Bachelor_project/data/pkl_files/half_orbit_means.pkl')

# %%
norm = np.ones(len(Half_orbit))
norm = signal.correlate(norm,norm)
lag= np.array(range(len(norm)))
lag=lag-lag[norm == max(norm)]
idx = (lag>-5) & (lag<15)

# %%
plt.figure()
plt.plot(lag[idx],norm[idx])

# %%
Half_orbit.head()
# Out:
#                      Density_corr       FAC  FAC_power       Density  \
# 2015-01-02 00:50:50  4.490907e-13  0.104478   0.284759  6.468488e-13
# 2015-01-02 01:37:45  5.746177e-13  0.139248   0.372618  6.987142e-13
# 2015-01-02 02:24:40  4.220675e-13  0.113231   0.390340  6.089699e-13
# 2015-01-02 03:11:35  5.656725e-13  0.181961   0.565810  6.858343e-13
# 2015-01-02 03:58:30  4.305537e-13  0.075313   0.165567  6.237317e-13
#
#                           Altitude  Orbit_nr  Hemisphere  AP_INDEX   Kp  \
# 2015-01-02 00:50:50  464222.287865       1.0         1.0      15.0  3.0
# 2015-01-02 01:37:45  475492.964700       1.0        -1.0      15.0  3.0
# 2015-01-02 02:24:40  464224.157119       2.0         1.0      15.0  3.0
# 2015-01-02 03:11:35  475506.057772       2.0        -1.0       4.0  1.0
# 2015-01-02 03:58:30  464035.397442       3.0         1.0       4.0  1.0
#
#                      F10_INDEX  BY_GSM  BZ_GSM  Bulk_speed    F10_Mean  \
# ...

# %%
corr=signal.correlate(Half_orbit.Density_corr.values,Half_orbit.FAC.values)
corr = corr/norm

# %%
plt.figure()
plt.plot(lag[idx],corr[idx])

# %%
active = Half_orbit[Half_orbit.Kp>4]
a_norm = np.ones(len(active))
a_norm = signal.correlate(a_norm,a_norm)
a_lag= np.array(range(len(a_norm)))
a_lag=a_lag-a_lag[a_norm == max(a_norm)]
a_idx = (a_lag>-5) & (a_lag<15)

# %%
a_corr=signal.correlate(active.Density.values,active.FAC.values)
a_corr = a_corr/a_norm
plt.figure()
plt.plot(a_lag[a_idx],a_corr[a_idx])

# %%
corr=signal.correlate(Half_orbit.Density_corr.values,Half_orbit.Kp.values)
corr = corr/norm
plt.figure()
plt.plot(lag[idx],corr[idx])

# %%
corr=signal.correlate(Half_orbit.Density_corr.values,Half_orbit.Density.values)
corr = corr/norm
plt.figure()
plt.plot(lag[idx],corr[idx])

# %%
dt = Half_orbit.index[2:]-Half_orbit.index[:-2]

# %%
plt.figure()
plt.plot(dt.values[abs(dt.values-np.median(dt.values))<np.timedelta64(10,'m')]/(10**9*60))

# %%
var1 = 'Density_corr'
var2 = 'FAC'
lag = 2

dt = Half_orbit.index[lag:]-Half_orbit.index[:-lag]
indx = abs(dt.values-np.median(dt.values))< lag*np.timedelta64(5,'m')

data = np.vstack([Half_orbit.loc[:,var1].values[lag:], Half_orbit.loc[:,var2].values[:-lag]])
Delayed_df = pd.DataFrame(np.transpose(data), index=Half_orbit.index[lag:], columns=[var1,var2])
Delayed_df = Delayed_df[indx]
dt_mean = np.mean(dt[indx])

# %%
Half_orbit.columns
# Out:
# Index(['Density_corr', 'FAC', 'FAC_power', 'Density', 'Altitude', 'Orbit_nr',
#        'Hemisphere', 'AP_INDEX', 'Kp', 'F10_INDEX', 'BY_GSM', 'BZ_GSM',
#        'Bulk_speed', 'F10_Mean', 'PyAmps'],
#       dtype='object')

# %%
df = Half_orbit
var1 = 'Density_corr'
var2 =['FAC','FAC_power','Kp','AP_INDEX','PyAmps','F10_INDEX','Altitude']
minlag = -5
maxlag = 15
lag_array = np.array(range(minlag,maxlag))
corr = np.zeros([len(var2),len(lag_array)])
N = np.zeros(len(lag_array))
dt_array = np.zeros(len(lag_array))
for i in range(len(lag_array)):
    lag = lag_array[i]
    
    if lag < 0:
        dt = df.index[-lag:]-df.index[:lag]
        indx = abs(dt.values-np.median(dt.values))< -lag*np.timedelta64(5,'m')
        data = np.hstack([df.loc[:,var1].values[:lag][:,np.newaxis], df.loc[:,var2].values[-lag:]])
        df_lag = pd.DataFrame(data, index=df.index[-lag:], columns=[var1]+var2)
        dt_mean = -np.mean(dt[indx]).astype('float')
    if lag > 0:
        dt = df.index[lag:]-df.index[:-lag]
        indx = abs(dt.values-np.median(dt.values))< lag*np.timedelta64(5,'m')
        data = np.hstack([df.loc[:,var1].values[lag:][:,np.newaxis], df.loc[:,var2].values[:-lag]])
        df_lag = pd.DataFrame(data, index=df.index[lag:], columns=[var1]+var2)
        dt_mean = np.mean(dt[indx]).astype('float')
    if lag == 0:
        indx = np.ones(len(df)).astype(bool)
        data = np.hstack([df.loc[:,var1].values[:,np.newaxis], df.loc[:,var2].values])
        df_lag = pd.DataFrame(data, index=df.index, columns=[var1]+var2)
        dt_mean = 0
     
    corr[:,i] = df_lag[indx].corr().values[0,1:]
    N[i] = len(df_lag[indx])
    dt_array[i] = dt_mean/(10**9*60*60)

# %%
plt.figure()
for i in range(len(var2)):
    plt.plot(lag_array,corr[i,:],label = var2[i])
plt.legend()

# %%
plt.figure()
for i in range(len(var2)):
    plt.plot(lag_array,corr[i,:],label = var2[i])
plt.legend()
