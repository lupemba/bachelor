# %% [markdown]
# # Test of Apexpy

# %% [markdown]
# Notes
# - apexPy does not take arrays for dates; shit
# - Bug in ApexPy. It uses the last defind object to convert instead of the one specified. Solution dont difene multiple apex objects at the same time. Define one and change it if you have to

# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from apexpy import Apex

# %%
FAC = pd.read_pickle('/home/simon/Desktop/Bachelor_project/data/pkl_files/FAC_filter.pkl')

# %%
start = Apex(date=FAC.index[0].date())  # datetime objects are also supported
finish = Apex(date=2030.0)

# %%
h=FAC.Radius/1000-6371

# %%
h_1= h
lat = FAC.Latitude.values
long = FAC.Longitude.values

# %%
FAC.index.values
# Out:
# numpy.datetime64('2015-03-01T00:00:00.500000000')

# %%
start = Apex(date=FAC.index[0].date()) 
mlat1, mlon1 = start.geo2apex(lat, long, h_1)
mlt1= start.mlon2mlt(mlon1, FAC.index.values, ssheight=450)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-83-74758934c7ab> in <module>()
#       1 start = Apex(date=FAC.index[0].date())
#       2 mlat1, mlon1 = start.geo2apex(lat, long, h_1)
# ----> 3 mlt1= start.mlon2mlt(mlon1, FAC.index.values, ssheight=450)
#
# ~/anaconda3/lib/python3.6/site-packages/apexpy/apex.py in mlon2mlt(self, mlon, datetime, ssheight)
#     497
#     498         """
# --> 499         ssglat, ssglon = helpers.subsol(datetime)
#     500         ssalat, ssalon = self.geo2apex(ssglat, ssglon, ssheight)
#     501
#
# ~/anaconda3/lib/python3.6/site-packages/apexpy/helpers.py in subsol(datetime)
#     172     """
#     173     # convert to year, day of year and seconds since midnight
# --> 174     year = datetime.year
#     175     doy = datetime.timetuple().tm_yday
#     176     ut = datetime.hour * 3600 + datetime.minute * 60 + datetime.second
#
# AttributeError: 'numpy.ndarray' object has no attribute 'year'

# %%
finish = Apex(date=FAC.index[-1].date())
mlat2, mlon2 = finish.geo2apex(lat, long, h_1)

mlt2= start.mlon2mlt(mlon2, FAC.index.values, ssheight=450)

# %%
plt.figure()

plt.plot(mlat1-mlat2)
plt.title('Effect of the choice of time mlat')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,'Effect of the choice of time mlat')

# %%
start = Apex(date=2013.3)
finish = Apex(date=2030.0)
start.convert(60, 15, 'geo', 'apex', height=300)  #### Bug in ApexPy. It uses date=2030 even tho start.convert is used
# Out:
# (57.469959259033203, 93.535964965820312)

# %%
finish.convert(60, 15, 'geo', 'apex', height=300)
# Out:
# (57.469959259033203, 93.535964965820312)

# %%
FAC.head()
# Out:
#                           Latitude  Longitude        Radius       IRC  \
# 2015-03-01 00:00:00.500  85.897902  97.311699  6.823980e+06  0.194692
# 2015-03-01 00:00:01.500  85.848743  97.880249  6.823981e+06  0.150217
# 2015-03-01 00:00:02.500  85.799181  98.435360  6.823983e+06  0.094356
# 2015-03-01 00:00:03.500  85.749228  98.977403  6.823984e+06  0.054410
# 2015-03-01 00:00:04.500  85.698901  99.506735  6.823986e+06  0.029266
#
#                          IRC_Error       FAC  FAC_Error  Flags     Flags_F  \
# 2015-03-01 00:00:00.500   0.200596 -0.194792   0.200699    0.0  22222224.0
# 2015-03-01 00:00:01.500   0.196639 -0.150293   0.196739    0.0  22222224.0
# 2015-03-01 00:00:02.500   0.192838 -0.094403   0.192935    0.0  22222224.0
# 2015-03-01 00:00:03.500   0.189181 -0.054437   0.189275    0.0  22222224.0
# 2015-03-01 00:00:04.500   0.185660 -0.029281   0.185752    0.0  22222224.0
#
#                          Flags_B  Flags_q  Orbit_nr  Hemisphere
# 2015-03-01 00:00:00.500      2.0      0.0       0.0         1.0
# 2015-03-01 00:00:01.500      2.0      0.0       0.0         1.0
# 2015-03-01 00:00:02.500      2.0      0.0       0.0         1.0
# 2015-03-01 00:00:03.500      2.0      0.0       0.0         1.0
# 2015-03-01 00:00:04.500      2.0      0.0       0.0         1.0

# %%
h[1]
# Out:
# 452.98112636892893

# %%
DNS.head()
# Out:
#                           Altitude   Latitude   Longitude  Local_solar_time  \
# 2015-03-01 00:00:10  467092.145535  85.117592  105.579979          6.833068
# 2015-03-01 00:00:20  467073.571848  84.569942  109.177030          7.075650
# 2015-03-01 00:00:30  467051.715982  84.004519  112.099728          7.273275
# 2015-03-01 00:00:40  467026.594584  83.425904  114.507952          7.436601
# 2015-03-01 00:00:50  466998.224698  82.837286  116.518385          7.573408
#
#                           Density  Orbit_nr  Hemisphere
# 2015-03-01 00:00:10  8.285023e-13       0.0         1.0
# 2015-03-01 00:00:20  8.265684e-13       0.0         1.0
# 2015-03-01 00:00:30  8.293079e-13       0.0         1.0
# 2015-03-01 00:00:40  8.313648e-13       0.0         1.0
# 2015-03-01 00:00:50  8.357428e-13       0.0         1.0

# %%
DNS = pd.read_pickle('/home/simon/Desktop/Bachelor_project/data/pkl_files/DNS.pkl')

# %%
DNS.loc[:,['Orbit_nr','Hemisphere']]
# Out:
#                      Orbit_nr  Hemisphere
# 2015-03-01 00:00:10       0.0         1.0
# 2015-03-01 00:00:20       0.0         1.0
# 2015-03-01 00:00:30       0.0         1.0
# 2015-03-01 00:00:40       0.0         1.0
# 2015-03-01 00:00:50       0.0         1.0
# 2015-03-01 00:01:00       0.0         1.0
# 2015-03-01 00:01:10       0.0         1.0
# 2015-03-01 00:01:20       0.0         1.0
# 2015-03-01 00:01:30       0.0         1.0
# 2015-03-01 00:01:40       0.0         1.0
# 2015-03-01 00:01:50       0.0         1.0
# 2015-03-01 00:02:10       0.0         1.0
# 2015-03-01 00:02:20       0.0         1.0
# 2015-03-01 00:02:30       0.0         1.0
# 2015-03-01 00:03:00       0.0         1.0
# 2015-03-01 00:03:10       0.0         1.0
# 2015-03-01 00:03:20       0.0         1.0
# 2015-03-01 00:03:30       0.0         1.0
# 2015-03-01 00:03:40       0.0         1.0
# 2015-03-01 00:03:50       0.0         1.0
# 2015-03-01 00:04:00       0.0         1.0
# 2015-03-01 00:04:10       0.0         1.0
# 2015-03-01 00:04:20       0.0         1.0
# 2015-03-01 00:04:30       0.0         1.0
# 2015-03-01 00:04:40       0.0         1.0
# 2015-03-01 00:04:50       0.0         1.0
# 2015-03-01 00:05:00       0.0         1.0
# 2015-03-01 00:05:10       0.0         1.0
# 2015-03-01 00:05:20       0.0         1.0
# 2015-03-01 00:05:30       0.0         1.0
# ...                       ...         ...
# 2015-03-31 23:55:00     476.0         1.0
# 2015-03-31 23:55:10     476.0         1.0
# 2015-03-31 23:55:20     476.0         1.0
# 2015-03-31 23:55:30     476.0         1.0
# 2015-03-31 23:55:40     476.0         1.0
# 2015-03-31 23:55:50     476.0         1.0
# 2015-03-31 23:56:00     476.0         1.0
# 2015-03-31 23:56:10     476.0         1.0
# 2015-03-31 23:56:20     476.0         1.0
# 2015-03-31 23:56:30     476.0         1.0
# 2015-03-31 23:56:40     476.0         1.0
# 2015-03-31 23:56:50     476.0         1.0
# 2015-03-31 23:57:00     476.0         1.0
# 2015-03-31 23:57:10     476.0         1.0
# 2015-03-31 23:57:20     476.0         1.0
# 2015-03-31 23:57:30     476.0         1.0
# 2015-03-31 23:57:40     476.0         1.0
# 2015-03-31 23:57:50     476.0         1.0
# 2015-03-31 23:58:00     476.0         1.0
# 2015-03-31 23:58:10     476.0         1.0
# 2015-03-31 23:58:20     476.0         1.0
# 2015-03-31 23:58:30     476.0         1.0
# 2015-03-31 23:58:40     476.0         1.0
# 2015-03-31 23:58:50     476.0         1.0
# 2015-03-31 23:59:00     476.0         1.0
# 2015-03-31 23:59:10     476.0         1.0
# 2015-03-31 23:59:20     476.0         1.0
# 2015-03-31 23:59:30     476.0         1.0
# 2015-03-31 23:59:40     476.0         1.0
# 2015-03-31 23:59:50     476.0         1.0
#
# [265902 rows x 2 columns]

# %% [markdown]
# ### Test of function

# %%
import My_functions_v2 as my
FAC = pd.read_pickle('/home/simon/Desktop/Bachelor_project/data/pkl_files/FAC_filter.pkl')
DNS = pd.read_pickle('/home/simon/Desktop/Bachelor_project/data/pkl_files/DNS.pkl')

# %%
my.add_apex_coords(DNS)

# %%
DNS.head()
# Out:
#                           Altitude   Latitude   Longitude  Local_solar_time  \
# 2015-01-02 00:00:10  486219.952352 -75.265076 -133.716770         15.026789
# 2015-01-02 00:00:20  486343.326722 -75.888605 -133.288864         15.058092
# 2015-01-02 00:00:30  486461.701815 -76.511095 -132.818524         15.092225
# 2015-01-02 00:00:40  486575.028978 -77.132404 -132.299675         15.129592
# 2015-01-02 00:00:50  486683.264306 -77.752361 -131.725048         15.170678
#
#                           Density  Orbit_nr  Hemisphere  mLatitude  mLongitude
# 2015-01-02 00:00:10  7.830560e-13       0.0        -1.0 -66.878181  -21.456318
# 2015-01-02 00:00:20  7.763505e-13       0.0        -1.0 -67.277733  -20.188025
# 2015-01-02 00:00:30  7.636256e-13       0.0        -1.0 -67.666161  -18.878735
# 2015-01-02 00:00:40  7.480111e-13       0.0        -1.0 -68.042892  -17.527630
# 2015-01-02 00:00:50  7.257936e-13       0.0        -1.0 -68.407341  -16.134010

# %%
# %matplotlib notebook
plt.figure()
plt.plot(DNS[DNS.Orbit_nr<3].mLatitude.values,'r')
plt.plot(DNS[DNS.Orbit_nr<3].Latitude.values,'k')
# Out:
# <img src="data:image/png;base64,..." width="640">
