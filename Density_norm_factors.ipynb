# %%
# %matplotlib notebook
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Normalization factors from matlab

# %%
nFactors = np.genfromtxt('/home/simon/Desktop/Bachelor_project/data/normalization_factors.csv', delimiter=',')
DNS = pd.read_pickle('/home/simon/Desktop/Bachelor_project/data/pkl_files/DNS.pkl')
omni = pd.read_pickle('/home/simon/Desktop/Bachelor_project/data/pkl_files/omni.pkl')

# %%
omni = omni.reindex(DNS.index,method='ffill')

# %%
nFactors[:,0]
# Out:
# array([1.274  , 1.2767 , 1.2793 , ..., 0.83685, 0.83471, 0.83255])

# %%
plt.figure()
plt.plot(DNS.Altitude.values,nFactors[:,0],'.b')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x = (omni.F10_INDEX.values+omni.F10_Mean.values)/2

# %%
plt.figure()
plt.plot(x,nFactors[:,1],'.b')
# Out:
# <img src="data:image/png;base64,..." width="640">
